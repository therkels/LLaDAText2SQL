# %% [markdown]
# ## Setup imports

# %%
import csv
import pandas as pd
from datasets import load_dataset
from database_interface import DatabaseHelper
from collections import Counter
# MODEL_OUTPUT_PATH = "/scratch/eecs595f25_class_root/eecs595f25_class/llada_data/synthetic_text_to_sql/output_sql.csv"
# MODEL_OUTPUT_PATH = "./eval.csv"
MODEL_OUTPUT_PATH = "/scratch/eecs595f25_class_root/eecs595f25_class/llada_data/baseline.csv"
OUTPUT_FILE_PATH = "/scratch/eecs595f25_class_root/eecs595f25_class/llada_data/synthetic_text_to_sql/valid_test.json"

# %% [markdown]
# ## Load in initial dataset

# %%
retrieved_dataset = load_dataset("json", data_files=OUTPUT_FILE_PATH)["train"]
print(f"retrieved dataset, info={retrieved_dataset}")
# Out:
# retrieved dataset, info=Dataset({
#     features: ['id', 'domain', 'domain_description', 'sql_complexity', 'sql_complexity_description', 'sql_task_type', 'sql_task_type_description', 'sql_prompt', 'sql_context', 'sql', 'sql_explanation'],
#     num_rows: 3434
# })

# %% [markdown]
# ## Load and merge the results with the examples

# %%
model_res_df = pd.read_csv(MODEL_OUTPUT_PATH)[:1000]
gold_standard_df = retrieved_dataset.to_pandas()
gold_standard_df = gold_standard_df.iloc[0:len(model_res_df)][[
    'id',
    'sql_complexity',
    'sql',
    'sql_context',
    'sql_prompt',
    'sql_explanation'
    
]]

eval_df = pd.merge(model_res_df, gold_standard_df,on='id')
# print(eval_df)
print(eval_df.iloc[4])
# Out:
# id                                                                 7
# out_sql                                                       [None]
# time_taken                                                 13.611531
# sql_complexity                                           aggregation
# sql                SELECT plant_name, SUM(co2_emission_per_ton_pr...
# sql_context        CREATE TABLE co2_emissions (id INT PRIMARY KEY...
# sql_prompt         Identify the top 2 plants with the highest CO2...
# sql_explanation    This query calculates the total CO2 emissions ...
# Name: 4, dtype: object

# %% [markdown]
# ## Setup Bag-of-cells to do analysis of each data cell in outputs (Gemini provided)

# %%
def get_cell_counts(df_gold, df_predicted):
    """
    Calculates Precision, Recall, and F1 score based on a 
    "Bag of Cells" (multiset of all values).
    """
    
    # --- 1. Flatten Gold DataFrame into a Counter ---
    # .values.flatten() turns the whole DF into a 1D numpy array
    # We must handle potential 'None' values which Counter might not like
    gold_cells = Counter([str(v) for v in df_gold.values.flatten() if v is not None])
    
    # --- 2. Flatten Predicted DataFrame into a Counter ---
    predicted_cells = Counter([str(v) for v in df_predicted.values.flatten() if v is not None])

    # --- 3. Calculate Scores ---
    
    # Handle the "divide by zero" case if no cells are returned
    total_gold = sum(gold_cells.values())
    total_predicted = sum(predicted_cells.values())

    # & (intersection) finds the element-wise minimum
    intersection = gold_cells & predicted_cells
    intersection_count = sum(intersection.values())
    
    # precision = intersection_count / total_predicted
    # recall = intersection_count / total_gold
        
    return intersection_count, total_predicted, total_gold


#test
df_gold_1 = pd.DataFrame([[1.0, 2000.0], [1.0, 2000.0], [2.0, 4000.0], [2.0, 4000.0]])
df_pred_1 = pd.DataFrame([[1.0, 2000.0], [2.0, 4000.0]])
p, r, f1 = get_cell_counts(df_gold_1, df_pred_1)
print(f"Example 1 F1: {f1:.2f} (P={p:.2f}, R={r:.2f})")


df_gold_2 = pd.DataFrame([['Commercial', 70.0]])
df_pred_2 = pd.DataFrame([[70.0]])
p, r, f1 = get_cell_counts(df_gold_2, df_pred_2)
print(f"Example 2 F1: {f1:.2f} (P={p:.2f}, R={r:.2f})")
# Out:
# Example 1 F1: 8.00 (P=4.00, R=4.00)
# Example 2 F1: 2.00 (P=1.00, R=1.00)

# %% [markdown]
# ## Iterate over examples and process the results!

# %%
sql_difficulty = eval_df['sql_complexity'].unique()
complexity_eval_res = {complexity:{"err_res":0, "correct":0, "parsable":0, "total":0, "cell_intersect":0, "cell_predict":0.000001, "cell_gold": 0.000001} for complexity in sql_difficulty}
print(complexity_eval_res)
count = 0
for index, row in eval_df.iterrows():
    model_sql_res = row.out_sql[1:len(row.out_sql)-1]
    # model_sql_res = row.out_sql
    complexity = row.sql_complexity
    complexity_eval_res[complexity]['total'] += 1
    if model_sql_res != "None":
        db_obj = DatabaseHelper(":memory:")
        db_obj.insert_data(row.sql_context)
        # Do minimal cleaning to pass the SQL
        cleaned_sql = model_sql_res.strip().strip("'").replace("\\n"," ").strip("\"")
        model_res, status = db_obj.fetch_data(cleaned_sql)
        
        if status != "failure":
            complexity_eval_res[complexity]['parsable'] += 1
        else:
            complexity_eval_res[complexity]['err_res'] += 1
            print(f"Prompt:{row.sql_prompt}")
            print("--------")
            print(f"SQL of res: {cleaned_sql}")
            print(f"SQL of truth: {row.sql}")
            print("--------")
            print()
        
            
        # If SQL parsed, increment score
        # complexity_eval_res[complexity]['parsable'] += 1
#         if model_res.empty:
#             # print(f"ID:{index} -- SQL that caused error:\n{model_sql_res}\n")
#             continue
            
        truth_res, status = db_obj.fetch_data(row.sql)
        # try:
        model_res_normalized = Counter(
            [tuple(sorted(row, key=str)) for row in model_res.values.tolist()]
        )
        truth_res_normalized = Counter(
            [tuple(sorted(row, key=str)) for row in truth_res.values.tolist()]
        )
        # except Exception as e:
        #     print("PARSING ISSUE")
        #     print(e)
        #     print("DATA:")
        #     print(truth_res)
        #     print(model_res)
        # if model_res_normalized != truth_res_normalized and complexity == "subqueries":
        #     print(f"DEBUG:\n Model res:\n{model_res_normalized}\nTruth res:\n{truth_res_normalized}\n")
        #     print(f"Prompt:{row.sql_prompt}")
        #     print(f"SQL of res: {cleaned_sql}")
        #     print(f"SQL of truth: {row.sql}")
        #     print(f"SQL explanation: {row.sql_explanation}")
        #     print("---------")
        # Give correct point for results that are matched
        # Note: This is a naive method which doesn't consider ORDER by. We will assume the non-ordered data considered 'correct'
        
        complexity_eval_res[complexity]['correct'] += 1 if model_res_normalized == truth_res_normalized else 0
        # get cell matches
        intersect_count, predict_count, gold_count = get_cell_counts(truth_res, model_res)
    
        # if complexity == "subqueries":
        #     print("MODEL RES")
        #     print(model_res)
        #     print("TRUTH RES")
        #     print(truth_res)
        #     print(get_cell_counts(truth_res, model_res))
        #     count += 1
        #     print("number of subqueires considered:",count)
        complexity_eval_res[complexity]['cell_intersect'] += intersect_count
        complexity_eval_res[complexity]['cell_predict'] += predict_count
        complexity_eval_res[complexity]['cell_gold'] += gold_count
# Out:
# {'basic SQL': {'err_res': 0, 'correct': 0, 'parsable': 0, 'total': 0, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1e-06}, 'aggregation': {'err_res': 0, 'correct': 0, 'parsable': 0, 'total': 0, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1e-06}, 'window functions': {'err_res': 0, 'correct': 0, 'parsable': 0, 'total': 0, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1e-06}, 'single join': {'err_res': 0, 'correct': 0, 'parsable': 0, 'total': 0, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1e-06}, 'multiple_joins': {'err_res': 0, 'correct': 0, 'parsable': 0, 'total': 0, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1e-06}, 'subqueries': {'err_res': 0, 'correct': 0, 'parsable': 0, 'total': 0, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1e-06}, 'set operations': {'err_res': 0, 'correct': 0, 'parsable': 0, 'total': 0, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1e-06}}
# Prompt:What is the average explainability score of creative AI applications in 'Europe' and 'North America' in the 'creative_ai' table?
# --------
# SQL of res: ["SELECT AVG(explainability_score) AS average_explainability_score  FROM creative_ai  WHERE c.region IN ('Europe', 'North America');"]
# SQL of truth: SELECT AVG(explainability_score) FROM creative_ai WHERE region IN ('Europe', 'North America');
# --------
#
# Prompt:How many accidents have been recorded for SpaceX and Blue Origin rocket launches?
# --------
# SQL of res: ["SELECT COUNT(*) AS number_of_accidents  FROM Accidents WHERE launch_provider IN ('SpaceX', 'Blue Origin');"]
# SQL of truth: SELECT launch_provider, COUNT(*) FROM Accidents GROUP BY launch_provider;
# --------
#
# Prompt:What is the maximum quantity of seafood sold in a single transaction?
# --------
# SQL of res: ['SELECT MAX(quantity) AS max_quantity FROM sales;']
# SQL of truth: SELECT MAX(quantity) FROM sales;
# --------
#
# Prompt:What is the total budget for movies released before 2010?
# --------
# SQL of res: ['SELECT SUM(budget) AS total_budget      FROM Movies_Release_Year      WHERE release_year < 2010;']
# SQL of truth: SELECT SUM(budget) FROM Movies_Release_Year WHERE release_year < 2010;
# --------
#
# Prompt:Identify the top 2 plants with the highest CO2 emissions per ton produced.
# --------
# SQL of res: [None]
# SQL of truth: SELECT plant_name, SUM(co2_emission_per_ton_produced) AS total_co2_emission FROM co2_emissions GROUP BY plant_name ORDER BY total_co2_emission DESC LIMIT 2;
# --------
#
# Prompt:What is the total cost of all climate communication projects that ended after 2010 in 'Antarctica'?
# --------
# SQL of res: [None]
# SQL of truth: SELECT SUM(total_cost) FROM climate_communication WHERE location = 'Antarctica' AND end_date >= '2010-12-31';
# --------
#
# Prompt:What is the average number of publications per researcher for researchers working at the 'National Geographic' organization?
# --------
# SQL of res: ["SELECT     AVG(publications) AS average_publications  FROM      researchers WHERE organization = 'National Geographic';"]
# SQL of truth: SELECT organization, AVG(publications) as avg_publications FROM researchers WHERE organization = 'National Geographic';
# --------
#
# Prompt:How many decentralized applications have been downloaded from the 'Asia-Pacific' region?
# --------
# SQL of res: ["SELECT SUM(dapp_downloads) / COUNT(dapp_id) AS average_dapp_downloads FROM dapp_ranking WHERE dapp_region = 'Asia-Pacific';"]
# SQL of truth: SELECT SUM(dapp_downloads) FROM dapp_ranking WHERE dapp_region = 'Asia-Pacific';
# --------
#
# Prompt:What is the maximum response time for emergency calls in the city of Los Angeles?
# --------
# SQL of res: ["SELECT MAX(response_time) AS max_response_time FROM emergency_calls  WHERE city = 'Los Angeles';"]
# SQL of truth: SELECT MAX(response_time) FROM emergency_calls WHERE city = 'Los Angeles';
# --------
#
# Prompt:What is the average cybersecurity contract value?
# --------
# SQL of res: ["SELECT      AVG(value) AS average.cybersecurity.value FROM      contracts WHERE      category = 'Cybersecurity';"]
# SQL of truth: SELECT AVG(value) as avg_value FROM contracts WHERE category = 'Cybersecurity';
# --------
#
# Prompt:What is the average number of military personnel per country involved in peacekeeping operations?
# --------
# SQL of res: ['SELECT AVG(military_personnel) OVER (ORDER BY country) AS average_military_personnel FROM Peacekeeping_Operations GROUP BY country;']
# SQL of truth: SELECT AVG(military_personnel) FROM Peacekeeping_Operations;
# --------
#
# Prompt:What is the maximum daily investment for each client?
# --------
# SQL of res: [None]
# SQL of truth: SELECT client_id, MAX(investment) OVER (PARTITION BY client_id ORDER BY client_id) as max_daily_investment FROM daily_investments;
# --------
#
# Prompt:List the ports with their total cargo weight for 'Fruit' type from the 'CARGO_HANDLING' table.
# --------
# SQL of res: ["SELECT p.PortID, p.PortName, SUM(c.Weight) AS TotalCargoWeight_Fruit FROM PORTS p JOIN CARGO_HANDLING c ON p.ID = c.PortID WHERE c.CargoType = 'Fruit';"]
# SQL of truth: SELECT P.PortName, SUM(CH.Weight) FROM PORTS P JOIN CARGO_HANDLING CH ON P.ID = CH.PortID WHERE CH.CargoType = 'Fruit' GROUP BY P.PortName;
# --------
#
# Prompt:What is the minimum fuel consumption of container ships built in 2016, grouped by container type?
# --------
# SQL of res: [None]
# SQL of truth: SELECT container_type, MIN(fuel_consumption) FROM container_ships WHERE year = 2016 GROUP BY container_type;
# --------
#
# Prompt:What is the sum of investments in healthcare for each region?
# --------
# SQL of res: ["SELECT i.region AS region, SUM(i.amount) AS total_investment FROM investments i WHERE i.sector = 'Healthcare' GROUP BY region AS region;"]
# SQL of truth: SELECT i.region, SUM(i.amount) FROM investments i WHERE i.sector = 'Healthcare' GROUP BY i.region;
# --------
#
# Prompt:How many donors are there in the 'South West' region?
# --------
# SQL of res: ["SELECT COUNT(*) AS southwest_count FROM Donors WHERE region = 'South West';"]
# SQL of truth: SELECT COUNT(*) FROM Donors WHERE region = 'South West';
# --------
#
# Prompt:What is the total amount donated to each program?
# --------
# SQL of res: [None]
# SQL of truth: SELECT Programs.ProgramName, SUM(Donations.DonationAmount) AS TotalDonatedAmount FROM Programs INNER JOIN DonorsPrograms ON Programs.ProgramID = DonorsPrograms.ProgramID INNER JOIN Donations ON DonorsPrograms.DonorID = Donations.DonorID GROUP BY Programs.ProgramName;
# --------
#
# Prompt:How many wind farms were installed in Canada between 2015 and 2018?
# --------
# SQL of res: ["SELECT COUNT(*) FROM wind_farms WHERE country = 'Canada' AND installation_year BETWEEN 2015 AND 2018;"]
# SQL of truth: SELECT COUNT(*) FROM wind_farms WHERE country = 'Canada' AND installation_year BETWEEN 2015 AND 2018;
# --------
#
# Prompt:List renewable energy projects in India with a budget between $50 million and $200 million.
# --------
# SQL of res: ["SELECT name, budget FROM renewable_project WHERE country = 'India' AND budget BETWEEN 50.0 AND 200.0;"]
# SQL of truth: SELECT name FROM renewable_project WHERE country = 'India' AND budget BETWEEN 50.0 AND 200.0;
# --------
#
# Prompt:What is the average energy rating for commercial buildings in Texas?
# --------
# SQL of res: ["SELECT AVG(energy_rating) AS average_energy_rating FROM energy_efficiency WHERE building_type = 'Commercial'   AND location = 'Texas';"]
# SQL of truth: SELECT building_type, AVG(energy_rating) FROM energy_efficiency WHERE building_type = 'Commercial' AND location = 'Texas';
# --------
#
# Prompt:What is the average running speed for each player in the 2020 World Cup?
# --------
# SQL of res: ['SELECT      player,     AVG(running_speed) AS average_running_speed FROM      world_cup GROUP BY      player;']
# SQL of truth: SELECT player, AVG(running_speed) FROM world_cup GROUP BY player;
# --------
#
# Prompt:What is the total number of points scored by players from Brazil in the NBA?
# --------
# SQL of res: ["SELECT SUM(points) AS total_points FROM players WHERE country = 'Brazil' AND league = 'NBA';"]
# SQL of truth: SELECT SUM(points) FROM players WHERE country = 'Brazil';
# --------
#
# Prompt:What is the total number of NGOs operating in Yemen and how many projects do they have?
# --------
# SQL of res: ["SELECT     COUNT(*) as total.ngos,     SUM(project_count) as total_projects FROM ngos WHERE country = 'Yemen';"]
# SQL of truth: SELECT country, SUM(project_count) FROM ngos GROUP BY country;
# --------
#
# Prompt:What is the total revenue generated by sales of eco-friendly materials?
# --------
# SQL of res: ["> SELECT SUM(revenue) AS total_revenue FROM Sales WHERE material IN ('Hemp', 'Recycled Polyester', 'Tencel', 'Bamboo');"]
# SQL of truth: SELECT SUM(revenue) FROM Sales WHERE material IN ('Organic Cotton', 'Hemp', 'Recycled Polyester', 'Tencel', 'Bamboo');
# --------
#
# Prompt:What are the names and total transactions of all Shariah-compliant financial institutions from the finance database?
# --------
# SQL of res: ['SELECT 1.name, 1.total_transactions     FROM shariah_compliant_institutions      FROM shariah_compliant_institutions;']
# SQL of truth: SELECT name, SUM(total_transactions) FROM shariah_compliant_institutions;
# --------
#
# Prompt:How many genetic research studies were conducted in the United Kingdom in 2019?
# --------
# SQL of res: ["SELECT COUNT(*) FROM genetic_research WHERE location = 'United Kingdom' AND start_date <= '2019-12-31';"]
# SQL of truth: SELECT COUNT(*) FROM genetic_research WHERE location = 'United Kingdom' AND start_date <= '2019-12-31' AND end_date >= '2019-01-01';
# --------
#
# Prompt:What is the number of female faculty members in the Physics department who have not been awarded any research grants?
# --------
# SQL of res: ["SELECT COUNT(*) AS female_faculty_count FROM faculty WHERE NOT EXISTS     SELECT 1 FROM research_grants WHERE faculty_id = faculty.id     WHERE faculty.department = 'Physics' AND faculty.gender = 'Female';"]
# SQL of truth: SELECT COUNT(*) FROM faculty f1 WHERE f1.department = 'Physics' AND f1.gender = 'Female' AND NOT EXISTS (SELECT 1 FROM research_grants rg WHERE rg.faculty_id = f1.id);
# --------
#
# Prompt:What is the average number of visitor reviews for heritage sites in each category?
# --------
# SQL of res: ['SELECT     Category,     AVG(Review) AS Average_Reviews_Category FROM     HeritageSitesReviews GROUP BY     Category;']
# SQL of truth: SELECT Category, AVG(Reviews) OVER (PARTITION BY Category) AS AvgReviews FROM HeritageSitesReviews;
# --------
#
# Prompt:What is the distribution of language preservation initiatives by initiative type?
# --------
# SQL of res: ['SELECT initiative, COUNT(*) as initiative_count FROM language_preservation_by_initiative  GROUP BY initiative;']
# SQL of truth: SELECT initiative, initiative_count FROM language_preservation_by_initiative;
# --------
#
# Prompt:What is the number of patients in India who received group therapy?
# --------
# SQL of res: [None]
# SQL of truth: SELECT COUNT(*) FROM patients INNER JOIN treatments ON patients.id = treatments.patient_id WHERE treatments.treatment = 'Group Therapy' AND patients.country = 'India';
# --------
#
# Prompt:Show the number of public works projects in California and their average resilience score
# --------
# SQL of res: ["SELECT COUNT(is_public_works) AS public_works_projects, AVG(resilience_score) AS average_resilience_score FROM Infrastructure WHERE location = 'California';"]
# SQL of truth: SELECT COUNT(*) as num_projects, AVG(resilience_score) as avg_resilience FROM Infrastructure WHERE location = 'California' AND is_public_works = TRUE;
# --------
#
# Prompt:What is the percentage of parolees who have reoffended in Texas, broken down by gender and race, for the years 2017 and 2018?
# --------
# SQL of res: [None]
# SQL of truth: SELECT c.year, c.gender, c.race, COUNT(c.parolee_id) AS parolees, AVG(CAST(c.reoffender AS FLOAT)) * 100 AS reoffender_percentage FROM parolee c WHERE c.year IN (2017, 2018) GROUP BY c.year, c.gender, c.race;
# --------
#
# Prompt:What is the total number of restorative justice cases per district?
# --------
# SQL of res: ['SELECT district.name, SUM(rj.cases) AS total_cases FROM district district JOIN restorative_justice rj ON rj.district_id = district.id;']
# SQL of truth: SELECT rj.district_id, SUM(rj.cases) AS total_cases FROM restorative_justice rj GROUP BY rj.district_id;
# --------
#
# Prompt:What is the total biomass of marine species in ascending order of depth?
# --------
# SQL of res: ["SELECT SUM(biomass) AS total_biomass, depth FROM biomass WHERE type_of_species LIKE 'Marine%' GROUP BY depth ORDER BY depth;"]
# SQL of truth: SELECT type, SUM(biomass) total_biomass FROM biomass GROUP BY type ORDER BY total_biomass ASC;
# --------
#
# Prompt:What is the average rating of movies by director in the Media database?
# --------
# SQL of res: [None]
# SQL of truth: SELECT Director, AVG(Rating) as AverageRating FROM DirectorMoviesRating GROUP BY Director;
# --------
#
# Prompt:What is the average rating of movies produced in the US between 2010 and 2020?
# --------
# SQL of res: [None]
# SQL of truth: SELECT AVG(rating) FROM movies WHERE production_year BETWEEN 2010 AND 2020 AND country = 'USA';
# --------
#
# Prompt:How many news items have been published in 'region1'?
# --------
# SQL of res: [None]
# SQL of truth: SELECT COUNT(*) FROM news WHERE region = 'region1';
# --------
#
# Prompt:What is the average word count for articles in the 'opinion' category?
# --------
# SQL of res: ["SELECT AVG(word_count) AS average_word_count FROM news WHERE category = 'Opinion';"]
# SQL of truth: SELECT AVG(word_count) FROM news WHERE category = 'Opinion';
# --------
#
# Prompt:What is the total prize money for esports events of the 'Simulation' genre?
# --------
# SQL of res: ["SELECT SUM(e.PrizeMoney) AS Total_PrizeMoney FROM EsportsEvents e JOIN Games g ON e.GameID = g.GameID WHERE e.GameName = 'GameC' AND g.Genre = 'Simulation';"]
# SQL of truth: SELECT SUM(PrizeMoney) FROM EsportsEvents JOIN Games ON EsportsEvents.GameName = Games.GameName WHERE Games.Genre = 'Simulation';
# --------
#
# Prompt:How many healthcare services are available in each region, and what is their ranking based on availability?
# --------
# SQL of res: [None]
# SQL of truth: SELECT Region, Service, ROW_NUMBER() OVER (PARTITION BY Region ORDER BY Service) AS Rank FROM HealthcareServices;
# --------
#
# Prompt:What is the total production of Neodymium in 2020, for companies in the APAC region?
# --------
# SQL of res: ["SELECT SUM(production.quantity) AS total_production FROM production WHERE   production.year = 2020   AND production.element = 'Neodymium'   AND companies.region = 'APAC';"]
# SQL of truth: SELECT SUM(quantity) FROM production JOIN companies ON production.company_id = companies.id WHERE production.element = 'Neodymium' AND production.year = 2020 AND companies.region = 'APAC';
# --------
#
# Prompt:What is the change in housing affordability in Portland from Q1 2021 to Q2 2021?
# --------
# SQL of res: ['SELECT MAX(affordability) AS change FROM portland_housing WHERE quarter = 2 OR (quarter = 1 AND year = 2021);']
# SQL of truth: SELECT (MAX(affordability) FILTER (WHERE year = 2021 AND quarter = 2) - MAX(affordability) FILTER (WHERE year = 2021 AND quarter = 1)) FROM portland_housing;
# --------
#
# Prompt:What is the difference in the total quantity of products sold in the 'apparel' category between this year and last year?
# --------
# SQL of res: [None]
# SQL of truth: SELECT product_category, (SUM(CASE WHEN year = 2022 THEN quantity ELSE 0 END) - SUM(CASE WHEN year = 2021 THEN quantity ELSE 0 END)) as quantity_diff FROM sales WHERE product_category = 'Apparel' GROUP BY product_category;
# --------
#
# Prompt:What are the maximum and minimum sizes of space debris for each source type?
# --------
# SQL of res: [None]
# SQL of truth: SELECT source_type, MAX(size) as max_size, MIN(size) as min_size FROM space_debris GROUP BY source_type;
# --------
#
# Prompt:Which countries are part of the EU and have had security incidents?
# --------
# SQL of res: ["SELECT country, date  FROM security_incidents WHERE country IN ('France', 'Germany', 'United Kingdom');"]
# SQL of truth: SELECT DISTINCT country FROM security_incidents WHERE country IN ('France', 'Germany', 'United Kingdom');
# --------
#
# Prompt:What is the total number of multimodal trips taken in Toronto, Canada using public transportation?
# --------
# SQL of res: ["SELECT COUNT(*) AS total_number_of_trips FROM multimodal_trips_canada WHERE city = 'Toronto' AND mode = 'public_transportation';"]
# SQL of truth: SELECT COUNT(*) FROM multimodal_trips_canada WHERE city = 'Toronto' AND mode LIKE '%public%';
# --------
#
# Prompt:Find the union names that have no reported workplace injuries.
# --------
# SQL of res: ['SELECT unions.name FROM unions WHERE id NOT IN  (SELECT injuries.id WHERE injuries.union_id IS NULL)']
# SQL of truth: SELECT name FROM unions WHERE id NOT IN (SELECT union_id FROM injuries);
# --------
#
# Prompt:What is the maximum weekly wage for workers in the 'retail' industry in unions?
# --------
# SQL of res: ["SELECT MAX(wage) AS max_wage  FROM workers  WHERE industry = 'retail'  GROUP BY      union_id;"]
# SQL of truth: SELECT MAX(wage) FROM workers JOIN unions ON workers.union_id = unions.id WHERE industry = 'retail';
# --------
#
# Prompt:Find the average travel time (in days) for vessels traveling between the Port of Valparaiso and the Port of Singapore in the first half of 2021, ranked by the average travel time in ascending order.
# --------
# SQL of res: [None]
# SQL of truth: SELECT route, AVG(travel_time) as avg_travel_time FROM VesselTravel WHERE route = 7 AND departure_date >= '2021-01-01' AND departure_date < '2021-07-01' GROUP BY route ORDER BY avg_travel_time ASC;
# --------
#
# Prompt:What is the count of vessels that have visited a specific port in a given month?
# --------
# SQL of res: ["SELECT COUNT(vessel_id) AS vessel_visits FROM Vessels AS vessels, PortCalls AS calls WHERE port = 'PortA' AND call_date >= '2021-01-01';"]
# SQL of truth: SELECT COUNT(PortCalls.id) FROM PortCalls WHERE PortCalls.port = 'PortA' AND PortCalls.call_date >= '2021-03-01' AND PortCalls.call_date <= '2021-03-31';
# --------
#
# Prompt:What is the average landfill tipping fee for each region?
# --------
# SQL of res: ['SELECT region,  AVG(tipping_fee) AS average_tipping_fee     FROM Landfill_All     GROUP BY region;']
# SQL of truth: SELECT region, AVG(tipping_fee) FROM Landfill_All GROUP BY region;
# --------
#
# Prompt:List algorithmic fairness scores for creative AI applications in Europe, ordered by score in descending order.
# --------
# SQL of res: ["SELECT application_name, fairness_score, region     FROM CreativeAI     WHERE region = 'Europe'     ORDER BY fairness_score DESC"]
# SQL of truth: SELECT * FROM CreativeAI WHERE region = 'Europe' ORDER BY fairness_score DESC;
# --------
#
# Prompt:Show algorithmic fairness scores for creative AI applications in Oceania, grouped by score in ascending order.
# --------
# SQL of res: ["SELECT application_name,  fairness_score, region FROM CreativeAI WHERE region = 'Oceania' ORDER BY fairness_score ASC;"]
# SQL of truth: SELECT * FROM CreativeAI WHERE region = 'Oceania' ORDER BY fairness_score ASC;
# --------
#
# Prompt:What is the average safety score for creative AI applications in Europe?
# --------
# SQL of res: ["SELECT AVG(safety_score) AS avg_safety_score FROM creative_ai  WHERE country LIKE '%Europe';"]
# SQL of truth: SELECT AVG(safety_score) FROM creative_ai WHERE country IN ('France', 'Germany', 'Spain');
# --------
#
# Prompt:What is the difference between the average satisfaction score of models trained on dataset D and dataset C, for each continent?
# --------
# SQL of res: ['SELECT continent, AVG(satisfaction) OVER datasetD, AS avgD - AVG(satisfaction) OVER datasetC, AS difference FROM models GROUP BY continent;']
# SQL of truth: SELECT continent, AVG(m.satisfaction) - (SELECT AVG(satisfaction) FROM models m2 WHERE m.continent = m2.continent AND m2.dataset = 'datasetC') FROM models m WHERE m.dataset = 'datasetD' GROUP BY continent;
# --------
#
# Prompt:What is the maximum crop yield in 'South America' in 2021?
# --------
# SQL of res: ["SELECT MAX(crop_yield) AS max_yield FROM crop_yields WHERE (     SELECT 1      FROM crop_yields     WHERE region = 'South America'     AND year = 2021);"]
# SQL of truth: SELECT MAX(crop_yield) FROM crop_yields WHERE year = 2021 AND region = 'South America';
# --------
#
# Prompt:What are the names and launch dates of all satellites with the type 'Navigation'?
# --------
# SQL of res: ["SELECT      name,      launch_date     FROM      Satellite      WHERE      satellite_type = 'Navigation';"]
# SQL of truth: SELECT s.name, s.launch_date FROM Satellite s WHERE s.type = 'Navigation';
# --------
#
# Prompt:What is the ratio of successful community education programs to total programs for each country, ordered by the success rate in descending order?
# --------
# SQL of res: [None]
# SQL of truth: SELECT Country, COUNT(*) FILTER (WHERE Success) * 1.0 / COUNT(*) as SuccessRate FROM CountryPrograms GROUP BY Country ORDER BY SuccessRate DESC;
# --------
#
# Prompt:What is the total nutrient value of feed in the 'feeding' table?
# --------
# SQL of res: ['SELECT SUM(nutrients) AS total_nutrients FROM feeding;']
# SQL of truth: SELECT SUM(nutrients) FROM feeding;
# --------
#
# Prompt:Which songs have the highest and lowest streams within their genre?
# --------
# SQL of res: ['SELECT SongName, Genre, MAX(Streams) AS HighestStreams, MIN(Streams) AS LOWESTStreams FROM Music GROUP BY Genre ORDER BY SongName;']
# SQL of truth: SELECT SongName, Genre, Streams, RANK() OVER(PARTITION BY Genre ORDER BY Streams DESC) AS Rank FROM Music;
# --------
#
# Prompt:What is the total construction labor cost for plumbers in Georgia?
# --------
# SQL of res: ["SELECT SUM(cost) AS total_labor_cost FROM construction_labor WHERE state = 'Georgia'    AND job = 'Plumber';"]
# SQL of truth: SELECT SUM(cost) FROM construction_labor WHERE state = 'Georgia' AND job = 'Plumber';
# --------
#
# Prompt:Find the total rainfall for each country and year, and rank them.
# --------
# SQL of res: ['SELECT Country, Year, SUM(Rainfall) AS Total_Rainfall FROM RainfallData GROUP BY Country, Year ORDER BY Total_Rainfall DESC;']
# SQL of truth: SELECT Country, Year, SUM(Rainfall) as TotalRainfall, RANK() OVER (PARTITION BY Year ORDER BY SUM(Rainfall) DESC) as Rank FROM RainfallData GROUP BY Country, Year;
# --------
#
# Prompt:What are the average climate finances spent by organizations in 'americas' and 'europe'?
# --------
# SQL of res: [None]
# SQL of truth: SELECT AVG(amount) FROM org_climate_finance WHERE region IN ('americas', 'europe');
# --------
#
# Prompt:Average healthcare access score in urban areas by year.
# --------
# SQL of res: ["SELECT Area, Year, AVG(Score) AS AverageAccessScore FROM HealthcareAccessScore WHERE Area = 'Urban' GROUP BY Area, Year"]
# SQL of truth: SELECT Year, AVG(Score) FROM HealthcareAccessScore WHERE Area = 'Urban' GROUP BY Year;
# --------
#
# Prompt:Show the sum of investments by year and industry
# --------
# SQL of res: [None]
# SQL of truth: SELECT investment_year, industry, SUM(investment_amount) as total_investments FROM investments GROUP BY investment_year, industry;
# --------
#
# Prompt:How many whale sharks have been spotted in each location?
# --------
# SQL of res: ['SELECT      location,      COUNT(*) AS number_of_sharks FROM      whale_sharks GROUP BY      location;']
# SQL of truth: SELECT location, COUNT(*) as spotted_count FROM whale_sharks GROUP BY location;
# --------
#
# Prompt:What is the average depth of all marine protected areas, grouped by country?
# --------
# SQL of res: ['SELECT country, AVG(avg_depth) AS avg_depth_per_country FROM marine_protected_areas GROUP BY country;']
# SQL of truth: SELECT country, AVG(avg_depth) FROM marine_protected_areas GROUP BY country;
# --------
#
# Prompt:What is the total number of transactions for the digital asset 'ETH' on a given date?
# --------
# SQL of res: ["SELECT SUM(transaction_count) AS total_eth_transactions FROM digital_assets WHERE asset_name = 'ETH';"]
# SQL of truth: SELECT transaction_count FROM digital_assets WHERE asset_name = 'ETH';
# --------
#
# Prompt:How many vegan makeup products were sold in India in Q1 of 2022?
# --------
# SQL of res: [None]
# SQL of truth: SELECT COUNT(*) FROM MakeupSales WHERE is_vegan = true AND country = 'India' AND sale_date BETWEEN '2022-01-01' AND '2022-03-31';
# --------
#
# Prompt:What is the total sales revenue of non-organic skincare products in the North American market?
# --------
# SQL of res: ["SELECT SUM(revenue) AS total_revenue_of_non_organic  FROM SkincareSales  LEFT JOIN ProductIngredients  WHERE organic = FALSE  AND region = 'North America';"]
# SQL of truth: SELECT SUM(revenue) FROM SkincareSales INNER JOIN ProductIngredients ON SkincareSales.productID = ProductIngredients.productID WHERE organic = false AND region = 'North America';
# --------
#
# Prompt:What was the maximum ticket sales for any event in Tokyo?
# --------
# SQL of res: ["SELECT MAX(ticket_sales) AS max_ticket_sales  FROM  (SELECT id  FROM EventData   WHERE city = 'Tokyo' );"]
# SQL of truth: SELECT MAX(ticket_sales) FROM EventData WHERE city = 'Tokyo';
# --------
#
# Prompt:Which defense contracts have the highest total value, and what are their respective values?
# --------
# SQL of res: [None]
# SQL of truth: SELECT Contract_Name, Value FROM (SELECT Contract_Name, Value, ROW_NUMBER() OVER (ORDER BY Value DESC) as Rank FROM Defense_Contracts) as Ranked_Contracts WHERE Rank <= 3;
# --------
#
# Prompt:List all transactions with a value greater than $10,000, along with the customer ID and the transaction date, in descending order of transaction date?
# --------
# SQL of res: ['SELECT transaction_id AS transaction_id_1, customer_id AS transaction_customer_id_1, transaction_date AS transaction_date_1 FROM transactions WHERE transaction_value_1 > 10000 ORDER BY transaction_date_1 DESC;']
# SQL of truth: SELECT * FROM transactions WHERE transaction_value > 10000 ORDER BY transaction_date DESC;
# --------
#
# Prompt:What is the average account balance for customers in each investment strategy?
# --------
# SQL of res: ['SELECT c.strategy_name, AVG(c.account_balance) AS average_account_balance     FROM customers c     GROUP BY c.strategy_name;']
# SQL of truth: SELECT strategy_name, AVG(account_balance) FROM customers GROUP BY strategy_name;
# --------
#
# Prompt:What is the total number of high-risk accounts in the Northwest region?
# --------
# SQL of res: ["SELECT COUNT(*) AS total_high_risk_accounts FROM accounts_by_region  WHERE risk_level = 'high'    AND region = 'Northwest';"]
# SQL of truth: SELECT COUNT(*) FROM accounts_by_region WHERE region = 'Northwest' AND risk_level = 'high';
# --------
#
# Prompt:What is the total weight of cargo handled by each port in february_2022 from the cargo_handling table?
# --------
# SQL of res: ["SELECT port, SUM(weight) total_weight FROM cargo_handling WHERE date >= '2022-02-01' GROUP BY port;"]
# SQL of truth: SELECT port, SUM(weight) as february_total_weight FROM cargo_handling WHERE date BETWEEN '2022-02-01' AND '2022-02-28' GROUP BY port;
# --------
#
# Prompt:What is the average salary of employees in factories with a certain certification?
# --------
# SQL of res: ['SELECT AVG(e.salary) AS average_salary FROM employees e JOIN factories ON e.factory_id = f.factory_id WHERE factories.name IN  SELECT factories.name FROM factories WHERE factories_certified = TRUE']
# SQL of truth: SELECT AVG(employees.salary) FROM factories INNER JOIN employees ON factories.factory_id = employees.factory_id WHERE factories.certified = TRUE;
# --------
#
# Prompt:What is the minimum and maximum average age of healthcare workers in 'rural_hospitals' table?
# --------
# SQL of res: ['SELECT MIN(avg_age) AS min_workers_avg_age,         MAX(avg_age) AS max_workers_avg_age FROM rural_hospitals;']
# SQL of truth: SELECT MIN(avg_age), MAX(avg_age) FROM rural_hospitals;
# --------
#
# Prompt:Display the number of unique users who have streamed or downloaded music on each platform in Africa.
# --------
# SQL of res: ['SELECT      platform,     COUNT(DISTINCT user_count) as unique_user_count FROM platform_users_africa GROUP BY platform ORDER BY platform ASC;']
# SQL of truth: SELECT platform, user_count FROM platform_users_africa;
# --------
#
# Prompt:What is the average mental health score of students for each grade level, ordered by the average score?
# --------
# SQL of res: [None]
# SQL of truth: SELECT grade_id, AVG(mental_health_score) as avg_score FROM student_mental_health GROUP BY grade_id ORDER BY avg_score DESC;
# --------
#
# Prompt:How many renewable energy power plants are there in Texas?
# --------
# SQL of res: ["SELECT COUNT(*) AS total_power_plants_count FROM power_plants WHERE state = 'Texas' AND source_type IN ('Wind', 'Solar', 'Hydro');"]
# SQL of truth: SELECT SUM(count) FROM power_plants WHERE state = 'Texas';
# --------
#
# Prompt:What is the maximum solar capacity in Mexico?
# --------
# SQL of res: ["SELECT MAX(capacity) AS max_capacity FROM solar_capacity WHERE country = 'Mexico';"]
# SQL of truth: SELECT MAX(capacity) FROM solar_capacity WHERE country = 'Mexico';
# --------
#
# Prompt:Count the number of wells drilled by CompanyA
# --------
# SQL of res: ["SELECT COUNT(*) AS total_wells_by_companyA FROM wells WHERE company = 'CompanyA';"]
# SQL of truth: SELECT COUNT(*) FROM wells WHERE company = 'CompanyA';
# --------
#
# Prompt:What is the average number of points scored by each hockey player in the NHL?
# --------
# SQL of res: ['SELECT      name,      position,      AVG(points) as average_points  FROM      nhl_teams  GROUP BY      name,      position;']
# SQL of truth: SELECT position, AVG(points) FROM hockey_players JOIN nhl_teams ON hockey_players.id = nhl_teams.players_id GROUP BY position;
# --------
#
# Prompt:What is the average price of eco-friendly materials used in garment production across different countries?
# --------
# SQL of res: ['SELECT AVG(price) AS average_price  FROM eco_materials;']
# SQL of truth: SELECT AVG(price) as avg_price, country FROM eco_materials GROUP BY country;
# --------
#
# Prompt:Which sustainable materials are used by companies in the 'Asia-Pacific' region?
# --------
# SQL of res: ["SELECT c1.name, m1.material, m1.quantity AS m1.quantity FROM Companies AS c1 JOIN Materials AS m1 ON m1.company_id = c1.id  WHERE c1.region = 'Asia-Pacific';"]
# SQL of truth: SELECT DISTINCT Materials.material FROM Companies JOIN Materials ON Companies.id = Materials.company_id WHERE Companies.region = 'Asia-Pacific';
# --------
#
# Prompt:List all Shariah-compliant financial products offered in the Southeast Asian region
# --------
# SQL of res: ["SELECT product_name     FROM shariah_compliant_products     WHERE region = 'Southeast Asia';"]
# SQL of truth: SELECT product_name FROM shariah_compliant_products WHERE region = 'Southeast Asia';
# --------
#
# Prompt:How many volunteers are there in total, and how many of them are from Africa?
# --------
# SQL of res: [None]
# SQL of truth: SELECT COUNT(*), SUM(region = 'Africa') FROM volunteers;
# --------
#
# Prompt:Who are the top 3 donors for open data initiatives in the city of Chicago?
# --------
# SQL of res: [None]
# SQL of truth: SELECT d.name, d.amount FROM donors d WHERE d.city = 'Chicago' ORDER BY d.amount DESC LIMIT 3;
# --------
#
# Prompt:What is the average renewable energy capacity per project in each country?
# --------
# SQL of res: ['SELECT      country, AVG(capacity) AS average_capacity FROM      renewable_energy_projects GROUP BY      country;']
# SQL of truth: SELECT project_name, country, capacity, AVG(capacity) OVER (PARTITION BY country) AS avg_capacity FROM renewable_energy_projects;
# --------
#
# Prompt:How many tunnels in Washington state were constructed after 2010?
# --------
# SQL of res: ['SELECT COUNT(*) AS "number_of_tunnels" FROM tunnels WHERE state = \'WA\'   AND build_year > 2010;']
# SQL of truth: SELECT COUNT(*) FROM tunnels WHERE state = 'WA' AND build_year > 2010;
# --------
#
# Prompt:What is the total cost of all resilience projects in the state of 'California'?
# --------
# SQL of res: ["<sql     SELECT SUM(projects_x.cost) AS total_cost     FROM Infrastructure_Projects AS projects_x WHERE projects_x.state = 'California'; >"]
# SQL of truth: SELECT SUM(cost) FROM Infrastructure_Projects WHERE state = 'California';
# --------
#
# Prompt:What are the maximum and minimum depths of the Arctic Ocean?
# --------
# SQL of res: ["SELECT ocean_depths.ocean_depth, ocean_depths.ocean_max_depth, ocean_depths.ocean_min_depth FROM ocean_depths WHERE ocean = 'Arctic Ocean';"]
# SQL of truth: SELECT ocean, max_depth, min_depth FROM ocean_depths WHERE ocean = 'Arctic Ocean';
# --------
#
# Prompt:How many movies were released each year?
# --------
# SQL of res: ['SELECT      release_year,      COUNT(*) as movie_count FROM      movies GROUP BY      release_year  ;']
# SQL of truth: SELECT release_year, COUNT(*) FROM movies GROUP BY release_year;
# --------
#
# Prompt:What are the menu items with a sustainability score above 90 and their corresponding categories?
# --------
# SQL of res: ['SELECT item_name,         category  FROM Menu  WHERE sustainability_score >90;']
# SQL of truth: SELECT category, item_name FROM Menu WHERE sustainability_score > 90;
# --------
#
# Prompt:What is the total cost of ingredients for gluten-free dishes in the healthy menu?
# --------
# SQL of res: [None]
# SQL of truth: SELECT SUM(cost) FROM ingredients WHERE is_gluten_free = true;
# --------
#
# Prompt:What is the total number of employees by role at each mining site in the Western US?
# --------
# SQL of res: ["SELECT ms.name, role, COUNT(e.id) AS total_employees_by_role FROM employees e JOIN mining_sites ms ON site_id = ms.id WHERE location = 'Western US' GROUP BY ms.name, role;"]
# SQL of truth: SELECT mining_sites.name, role, COUNT(*) FROM mining_sites INNER JOIN employees ON mining_sites.id = employees.site_id GROUP BY mining_sites.name, role, location;
# --------
#
# Prompt:What is the total number of customer complaints regarding mobile and broadband services by region?
# --------
# SQL of res: ["SELECT region, COUNT(complaint_id) AS total_complaints FROM complaints WHERE complaint_type IN ('Mobile', 'Broadband') GROUP BY region;"]
# SQL of truth: SELECT region, COUNT(*) AS total_complaints FROM complaints WHERE complaint_type IN ('Mobile', 'Broadband') GROUP BY region;
# --------
#
# Prompt:What is the minimum depth at which a deep-sea expedition has been conducted in the Atlantic Ocean?
# --------
# SQL of res: ["SELECT min_depth FROM (     SELECT MIN(depth) AS min_depth ) FROM deep_sea_expeditions WHERE location = 'Atlantic Ocean';"]
# SQL of truth: SELECT MIN(depth) FROM deep_sea_expeditions WHERE location = 'Atlantic Ocean';
# --------
#
# Prompt:Which region has the highest number of esports events?
# --------
# SQL of res: ['SELECT Region, COUNT(*) FROM Events GROUP BY Region ORDER BY COUNT(*)']
# SQL of truth: SELECT Region, COUNT(*) as EventCount FROM Events GROUP BY Region ORDER BY EventCount DESC LIMIT 1
# --------
#
# Prompt:What are the top 3 countries with the most rare earth element production?
# --------
# SQL of res: [None]
# SQL of truth: SELECT country FROM production ORDER BY production DESC LIMIT 3;
# --------
#
# Prompt:Count the number of properties in Austin with a listing price below $400,000 and sustainable features.
# --------
# SQL of res: ["SELECT COUNT(*) AS property_count FROM properties WHERE city = 'Austin'   AND listing_price < 400000 AND sustainable = true;"]
# SQL of truth: SELECT COUNT(*) FROM properties WHERE city = 'Austin' AND listing_price < 400000 AND sustainable = true;
# --------
#
# Prompt:How many wind power projects were completed in Germany and Sweden in 2019 and 2020?
# --------
# SQL of res: [None]
# SQL of truth: SELECT country, COUNT(*) FROM wind_projects_2 WHERE completion_year IN (2019, 2020) GROUP BY country;
# --------
#
# Prompt:What is the average energy efficiency rating for residential buildings in the United States, grouped by state?
# --------
# SQL of res: ['SELECT      state, AVG(rating) AS average_rating FROM      Residential_Buildings GROUP BY      state;']
# SQL of truth: SELECT state, AVG(rating) AS avg_rating FROM Residential_Buildings GROUP BY state;
# --------
#
# Prompt:Find the number of vegetarian dishes that are not offered at any restaurant.
# --------
# SQL of res: ["SELECT ( SELECT COUNT(*) FROM dishes WHERE type = 'vegetarian' AND id NOT IN (SELECT dish_id FROM menus) ) vegetarian_count FROM dishes WHERE type = 'vegetarian' GROUP BY vegetarian_count ORDER BY id;"]
# SQL of truth: SELECT COUNT(*) FROM dishes WHERE type = 'vegetarian' AND id NOT IN (SELECT dish_id FROM menus);
# --------
#
# Prompt:What is the total revenue for 'Breakfast' menu items in the 'Downtown' location?
# --------
# SQL of res: ["SELECT SUM(revenue) AS total_revenue     FROM menus     WHERE dish_type = 'Breakfast'       AND location = 'Downtown';"]
# SQL of truth: SELECT SUM(r.revenue) FROM menus m JOIN revenue r ON m.menu_id = r.menu_id WHERE m.dish_type = 'Breakfast' AND m.location = 'Downtown';
# --------
#
# Prompt:What is the total mass of space objects in high Earth orbit?
# --------
# SQL of res: [None]
# SQL of truth: SELECT SUM(mass) FROM space_objects_heo;
# --------
#
# Prompt:What is the average severity of vulnerabilities in the 'Malware' category?
# --------
# SQL of res: ["SELECT AVG(severity) AS avg_severity FROM vulnerabilities WHERE category='Malware';"]
# SQL of truth: SELECT AVG(severity = 'Critical') + AVG(severity = 'High') * 0.75 + AVG(severity = 'Medium') * 0.5 + AVG(severity = 'Low') * 0.25 as average FROM vulnerabilities WHERE category = 'Malware';
# --------
#
# Prompt:How many bicycle-sharing systems are available in the 'transportation_systems' table?
# --------
# SQL of res: ["SELECT COUNT(bicycle_sharing_systems) AS bicycle_sharing_system_count FROM (SELECT id FROM transportation_systems WHERE system_type = 'Bicycle-Sharing');"]
# SQL of truth: SELECT COUNT(*) FROM transportation_systems WHERE system_type = 'Bicycle-Sharing';
# --------
#
# Prompt:What is the maximum number of bike-share trips in a day in Paris?
# --------
# SQL of res: ["```sql SELECT MAX(trips_per_day) AS max_trips_per_day FROM bike_trips  WHERE city = 'Paris'; ```"]
# SQL of truth: SELECT MAX(trips_per_day) FROM bike_trips WHERE city = 'Paris';
# --------
#
# Prompt:What is the average claim amount in the 'East' region?
# --------
# SQL of res: ["SELECT AVG(Amount) AS average_amount FROM Claims WHERE Region = 'East';"]
# SQL of truth: SELECT AVG(Amount) FROM Claims WHERE Region = 'East';
# --------
#
# Prompt:What is the total number of electric vehicles adopted in Canada and the UK?
# --------
# SQL of res: ["SELECT COUNT(*) AS TotalNumberOfElectricVehicles  FROM ElectricVehicleAdoptionCAUK  WHERE (Country = 'Canada' OR Country = 'United Kingdom');"]
# SQL of truth: SELECT SUM(AdoptionRate) FROM ElectricVehicleAdoptionCAUK WHERE IsCAUK IN (1, 2);
# --------
#
# Prompt:How many landfills are there in Tokyo with a capacity over 100,000 tons?
# --------
# SQL of res: [None]
# SQL of truth: SELECT COUNT(*) FROM landfills WHERE location = 'Tokyo' AND capacity > 100000;
# --------
#
# Prompt:What is the maximum duration of 'Yoga' workouts in the 'workout_data' table?
# --------
# SQL of res: ["SELECT MAX(duration) AS yoga_max_workout_duration FROM workout_data WHERE lower(workout_type) = 'Yoga' AND workout_type = 'Yoga';"]
# SQL of truth: SELECT MAX(duration) as max_duration FROM workout_data WHERE workout_type = 'Yoga';
# --------
#
# Prompt:What is the total investment in agricultural innovation in the 'Investment_Data' table for each crop type?
# --------
# SQL of res: ['```sql SELECT crop_type,  SUM(investment_amount) AS total_investment FROM Investment_Data GROUP BY crop_type ```']
# SQL of truth: SELECT crop_type, SUM(investment_amount) FROM Investment_Data GROUP BY crop_type;
# --------
#
# Prompt:List the top 3 countries with the highest number of satellites launched
# --------
# SQL of res: [None]
# SQL of truth: SELECT Country, COUNT(*) as SatelliteCount, RANK() OVER(ORDER BY COUNT(*) DESC) as Rank FROM Satellites GROUP BY Country HAVING COUNT(*) > 0 ORDER BY Rank;
# --------
#
# Prompt:What is the total number of fish in fish farms located in the North Atlantic Ocean?
# --------
# SQL of res: ["SELECT SUM(number_of_fish) AS number_of_fish_in_Atlantic     FROM fish_farms     WHERE location = 'North Atlantic Ocean';"]
# SQL of truth: SELECT SUM(number_of_fish) FROM fish_farms WHERE location = 'North Atlantic Ocean';
# --------
#
# Prompt:What was the total attendance at poetry readings in San Francisco?
# --------
# SQL of res: ["SELECT SUM(attendance) AS total_attendance FROM events WHERE event_type = 'Poetry Reading'   AND city = 'San Francisco';"]
# SQL of truth: SELECT SUM(attendance) FROM events WHERE event_type = 'Poetry Reading' AND city = 'San Francisco';
# --------
#
# Prompt:What's the average rating of K-dramas released between 2016 and 2018?
# --------
# SQL of res: ['SELECT AVG(rating) AS average_rating FROM kdramas WHERE release_year BETWEEN 2016 AND 2018;']
# SQL of truth: SELECT AVG(rating) FROM kdramas WHERE release_year BETWEEN 2016 AND 2018;
# --------
#
# Prompt:What is the obesity rate among adults in North American countries in 2019?
# --------
# SQL of res: [None]
# SQL of truth: SELECT Country, Continent, ObesityRate FROM ObesityRates WHERE Continent = 'North America' AND Year = 2019;
# --------
#
# Prompt:What is the minimum depth at which a marine species can be found?
# --------
# SQL of res: [None]
# SQL of truth: SELECT MIN(min_depth) FROM marine_species_depths;
# --------
#
# Prompt:What is the minimum ocean temperature, grouped by ocean basin?
# --------
# SQL of res: ['SELECT ocean_basin,         MIN(temperature) AS min_temperature FROM ocean_temperature GROUP BY ocean_basin  ORDER BY ocean_basin;']
# SQL of truth: SELECT ocean_basin, MIN(temperature) FROM ocean_temperature GROUP BY ocean_basin;
# --------
#
# Prompt:What is the total number of transactions performed by all decentralized applications?
# --------
# SQL of res: ['SELECT      COUNT(id) AS total_transactions  FROM      transactions  WHERE app_id = 1;']
# SQL of truth: SELECT COUNT(*) FROM transactions;
# --------
#
# Prompt:What is the maximum number of pieces created by an artist who has used oil as a medium?
# --------
# SQL of res: ["SELECT MAX(pieces) AS max_pieces FROM artists_oil WHERE medium = 'oil';"]
# SQL of truth: SELECT MAX(pieces) FROM artists_oil WHERE medium = 'oil';
# --------
#
# Prompt:What is the earliest year a peacekeeping operation was conducted in 'Asia'?
# --------
# SQL of res: ["SELECT MIN(YEAR) AS earliest_years FROM     FROM Peacekeeping_Years AS peacekeeping_years     WHERE peacekeeping_years.location = 'Asia';"]
# SQL of truth: SELECT MIN(year) FROM Peacekeeping_Years WHERE location = 'Asia';
# --------
#
# Prompt:What is the total number of peacekeeping operations conducted by each country, ranked from highest to lowest?
# --------
# SQL of res: [None]
# SQL of truth: SELECT Country, SUM(Operations) OVER (PARTITION BY Country ORDER BY Year ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW) AS TotalOperations, RANK() OVER (ORDER BY SUM(Operations) DESC) AS PeacekeepingRank FROM PeacekeepingOperations GROUP BY Country ORDER BY PeacekeepingRank;
# --------
#
# Prompt:Which cities have donors but no active programs?
# --------
# SQL of res: [None]
# SQL of truth: SELECT city FROM Donors WHERE city NOT IN (SELECT city FROM Programs);
# --------
#
# Prompt:What is the difference in total points scored between the home and away games for each team in the 2020 baseball season?
# --------
# SQL of res: ['SELECT      team_id,     points_home - points_away AS points_difference,     team_name FROM     baseball_season;']
# SQL of truth: SELECT team_name, (points_home - points_away) as diff FROM baseball_season;
# --------
#
# Prompt:What is the total number of schools in rural areas?
# --------
# SQL of res: ["SELECT      COUNT(*) AS total_schools FROM      schools  WHERE      location = 'Rural';"]
# SQL of truth: SELECT COUNT(*) FROM schools WHERE location = 'Rural';
# --------
#
# Prompt:What is the total revenue for each warehouse after a 10% discount?
# --------
# SQL of res: [None]
# SQL of truth: SELECT warehouse_id, revenue * 0.9 FROM warehouse_revenue;
# --------
#
# Prompt:What is the distribution of biotech startup funding sources?
# --------
# SQL of res: ['SELECT funding_source_type, COUNT(*) AS funding_source_distribution FROM funding_sources GROUP BY funding_source_type;']
# SQL of truth: SELECT funding_source_type, COUNT(*) FROM funding_sources GROUP BY funding_source_type
# --------
#
# Prompt:List faculty diversity metrics including the number of female, male, and non-binary faculty members in the Mathematics department
# --------
# SQL of res: ["SELECT SUM(gender = 'Female') AS female_count, SUM(gender = 'Male') AS male_count, SUM(gender = 'Non-binary') AS nb_count FROM Faculty WHERE NOT(department_id = 3);"]
# SQL of truth: SELECT f.gender, COUNT(*) as num_faculty FROM Faculty f WHERE f.department_id = (SELECT id FROM Department WHERE name = 'Mathematics') GROUP BY f.gender;
# --------
#
# Prompt:What is the total number of research grants awarded by department?
# --------
# SQL of res: ['SELECT COUNT(grant_id) AS totalresearch_grants FROM research_grants JOIN department d ON dept_name = d.dept_name GROUP BY dept_name']
# SQL of truth: SELECT dept_name, SUM(grant_amount) FROM research_grants GROUP BY dept_name;
# --------
#
# Prompt:What is the maximum energy consumption by a green building project in Asia?
# --------
# SQL of res: ["SELECT MAX(energy_consumption) AS max_energy_consumption  FROM green_buildings  WHERE country LIKE 'Asia' AND country NOT LIKE 'Asia';"]
# SQL of truth: SELECT MAX(energy_consumption) FROM green_buildings WHERE country = 'India' OR country = 'China' OR country = 'Japan';
# --------
#
# Prompt:What is the distribution of users by age group for each virtual tour?
# --------
# SQL of res: ['SELECT tour_id, age_group, COUNT(user_id) AS user_count FROM virtual_tour_users GROUP BY     tour_id ORDER BY     age_group;']
# SQL of truth: SELECT tour_id, age_group, COUNT(*) as user_count FROM virtual_tour_users GROUP BY tour_id, age_group;
# --------
#
# Prompt:What is the total number of traditional art pieces created in each region with a population greater than 500,000?
# --------
# SQL of res: ['SELECT region.id, region.name, COUNT(type) AS total.tritional.art_pieces SELECT type FROM regions WHERE population > 500000;']
# SQL of truth: SELECT r.name, COUNT(ap.id) FROM regions r JOIN art_pieces ap ON r.id = ap.region_id WHERE r.population > 500000 GROUP BY r.id;
# --------
#
# Prompt:Which mental health conditions were treated most frequently in Canada during 2022?
# --------
# SQL of res: ["SELECT patient_condition, COUNT(*) AS treatment_count FROM treatments WHERE patient_country = 'Canada' AND treatment_date LIKE '%-01' AND year = 2022 ORDER BY treatment_count DESC  LIMIT 1;"]
# SQL of truth: SELECT conditions.condition, COUNT(conditions.condition) AS count FROM conditions JOIN patients ON conditions.patient_id = patients.id JOIN treatments ON patients.id = treatments.patient_id WHERE patients.country = 'Canada' AND treatments.treatment_date >= '2022-01-01' AND treatments.treatment_date < '2023-01-01' GROUP BY conditions.condition ORDER BY count DESC LIMIT 1;
# --------
#
# Prompt:How many marine conservation initiatives were launched in the Indian Ocean in 2015 and 2016?
# --------
# SQL of res: [None]
# SQL of truth: SELECT COUNT(*) FROM marine_conservation_initiatives WHERE region = 'Indian Ocean' AND year IN (2015, 2016);
# --------
#
# Prompt:How many pollution control initiatives are in the South Pacific Ocean?
# --------
# SQL of res: [None]
# SQL of truth: SELECT Oceans.ocean, COUNT(SouthPacificPollution.initiative_name) FROM Oceans LEFT JOIN SouthPacificPollution ON Oceans.ocean = SouthPacificPollution.location GROUP BY Oceans.ocean;
# --------
#
# Prompt:How many species of marine life are present in the Southern Ocean?
# --------
# SQL of res: ["SELECT COUNT(*) AS total_species_count; FROM ( SELECT COUNT(*) AS species_count FROM marine_life  WHERE location = 'Southern Ocean'; );"]
# SQL of truth: SELECT COUNT(DISTINCT species_name) FROM marine_life WHERE location = 'Southern Ocean';
# --------
#
# Prompt:What are the names and locations of marine research stations in the Atlantic Ocean?
# --------
# SQL of res: ["SELECT station_name, latitude, longitude FROM Research_Station WHERE ocean_name = 'Atlantic';"]
# SQL of truth: SELECT Research_Station.station_name, latitude, longitude FROM Research_Station WHERE ocean_name = 'Atlantic';
# --------
#
# Prompt:What is the average depth of ocean floor mapping projects located in the Arctic region?
# --------
# ...
# --------
# SQL of res: ["SELECT AVG(retail_price * strain_type = 'Indica' - strain_type = 'Sativa') FROM DispensarySales WHERE state = 'California';"]
# SQL of truth: SELECT AVG(CASE WHEN strain_type = 'Indica' THEN retail_price ELSE NULL END) - AVG(CASE WHEN strain_type = 'Sativa' THEN retail_price ELSE NULL END) as price_difference FROM DispensarySales WHERE state = 'California';
# --------
#
# Prompt:What is the total pro bono hours for attorneys who work on civil cases, ordered by hours?
# --------
# SQL of res: [None]
# SQL of truth: SELECT case_type, SUM(hours) as total_hours FROM case_outcomes WHERE case_type = 'Civil' GROUP BY case_type ORDER BY total_hours DESC;
# --------
#
# Prompt:What is the maximum investment in climate finance for a single project in Europe?
# --------
# SQL of res: [None]
# SQL of truth: SELECT MAX(investment) FROM climate_finance_projects WHERE country IN ('Germany', 'France', 'UK', 'Italy', 'Spain');
# --------
#
# Prompt:What was the total R&D expenditure for 'DrugA'?
# --------
# SQL of res: [None]
# SQL of truth: SELECT SUM(amount) FROM rd_expenditure WHERE drug_name = 'DrugA';
# --------
#
# Prompt:What was the total sales revenue of all drugs in Q4 2020 in Mexico?
# --------
# SQL of res: ["SELECT SUM(revenue) AS total_revenue FROM sales WHERE  year  = 2020 AND quarter  = 'Q4'"]
# SQL of truth: SELECT SUM(revenue) FROM sales WHERE quarter = 'Q4' AND year = 2020;
# --------
#
# Prompt:What is the maximum and minimum funding amount by quarter for companies founded in the US?
# --------
# SQL of res: ["SELECT f.quarter, MAX(f.amount) max_funding, MIN(f.amount) min_amount FROM funding f JOIN companies c ON f.company_id = c.id WHERE c.country = 'USA' GROUP BY f.quarter;"]
# SQL of truth: SELECT companies.country, funding.quarter, MAX(funding.amount) as max_funding, MIN(funding.amount) as min_funding FROM funding JOIN companies ON funding.company_id = companies.company_id WHERE companies.country = 'USA' GROUP BY companies.country, funding.quarter;
# --------
#
# Prompt:What is the percentage of students who received accommodations for mobility impairments?
# --------
# SQL of res: ["SELECT (COUNT(s.student_id)/COUNT(a.student_id)) * 100  FROM Students s JOIN Accommodations a ON s.student_id=a.student_id WHERE a.accommodation_type = 'mobility impairments';"]
# SQL of truth: SELECT (COUNT(DISTINCT student_id) * 100.0 / (SELECT COUNT(DISTINCT student_id) FROM Students)) as percentage FROM Accommodations WHERE student_id IN ( SELECT student_id FROM DisabilityTypes WHERE disability_type = 'Mobility Impairment');
# --------
#
# Prompt:What is the total budget allocated for physical disability accommodations in South America?
# --------
# SQL of res: [None]
# SQL of truth: SELECT SUM(Budget) FROM Accommodations WHERE Type LIKE 'Physical%' AND Region = 'South America';
# --------
#
# Prompt:What is the average depth of all trenches in the Southern Ocean?
# --------
# SQL of res: ["SELECT      AVG(depth) AS average_depth FROM      oceanography WHERE      location LIKE 'Southern Ocean';"]
# SQL of truth: SELECT AVG(depth) FROM oceanography WHERE location = 'Southern Ocean Trench';
# --------
#
# Prompt:What are the total unit sales of cosmetics products that are free from parabens and sulfates?
# --------
# SQL of res: ['SELECT SUM(pss.unit_sales) AS total_unit_sales FROM product_safety ps JOIN product_sales ps ON ps.product_name = ps.product_name WHERE is_paraben_free = TRUE AND is_sulfate_free = TRUE;']
# SQL of truth: SELECT SUM(product_sales.unit_sales) FROM product_sales JOIN product_safety ON product_sales.product_name = product_safety.product_name WHERE product_safety.is_paraben_free = true AND product_safety.is_sulfate_free = true;
# --------
#
# Prompt:What is the total number of military equipment in the 'naval' category, by country?
# --------
# SQL of res: ["SELECT country, SUM(number) AS total_naval_equipment FROM military_equipment_2 WHERE category = 'Naval' GROUP BY country;"]
# SQL of truth: SELECT country, SUM(number) as total_naval FROM military_equipment_2 WHERE category = 'Naval' GROUP BY country;
# --------
#
# Prompt:What is the average gross tonnage of container vessels in each port?
# --------
# SQL of res: ["SELECT p.PortName, AVG(v.GrossTonnage) AS AverageTonnage FROM Port p JOIN Vessel v ON p.PortID = v.PortID WHERE VesselType = 'Container' GROUP BY p.PortName"]
# SQL of truth: SELECT PortName, AVG(GrossTonnage) AS AvgGrossTonnage FROM Vessel v JOIN Port p ON v.PortID = p.PortID WHERE VesselType = 'Container' GROUP BY PortName;
# --------
#
# Prompt:Identify the total number of machines in the 'Circular Economy' category that were manufactured before 2010.
# --------
# SQL of res: ["SELECT COUNT(*) AS TotalNumberOfMachines FROM Machines WHERE Category = 'Circular Economy' AND ManufacturingYear < 2010;"]
# SQL of truth: SELECT COUNT(*) FROM Machines WHERE Category = 'Circular Economy' AND ManufacturingYear < 2010;
# --------
#
# Prompt:Show the total number of artifacts excavated from site 'Timgad'.
# --------
# SQL of res: ["SELECT COUNT(artifact_id) AS total_artifacts_excavated_timgad FROM artifact_timgad WHERE site_name = 'Timgad';"]
# SQL of truth: SELECT COUNT(*) FROM artifact_timgad WHERE site_name = 'Timgad';
# --------
#
# Prompt:Find the total value of social impact bonds issued by each organization.
# --------
# SQL of res: ['SELECT organization_name, SUM(value) AS total_value FROM social_impact_bonds GROUP BY organization_name;']
# SQL of truth: SELECT organization_name, SUM(value) as total_value FROM social_impact_bonds GROUP BY organization_name;
# --------
#
# Prompt:List all social impact investments in the Healthcare sector with ESG scores above 80, ordered by investment date and ESGScore, including only investments made by investors from the United Kingdom.
# --------
# SQL of res: ["SELECT * FROM SocialImpactInvestments WHERE Sector='Healthcare' AND ESGScore > 80 AND InvestorCountry = 'UK' ORDER BY InvestmentDate, ESGScore"]
# SQL of truth: SELECT * FROM SocialImpactInvestments WHERE Sector = 'Healthcare' AND ESGScore > 80 AND InvestorCountry = 'UK' ORDER BY InvestmentDate, ESGScore DESC;
# --------
#
# Prompt:What is the ranking of national security measures for Russia based on the publication date?
# --------
# SQL of res: [None]
# SQL of truth: SELECT title, description, agency, date, ROW_NUMBER() OVER (PARTITION BY agency ORDER BY date DESC) as ranking FROM national_security WHERE agency = 'Russian Government';
# --------
#
# Prompt:What are the total views for all open education resources in each language and format, ordered by views?
# --------
# SQL of res: [None]
# SQL of truth: SELECT language, format, SUM(views) as total_views FROM open_education_resources GROUP BY language, format ORDER BY total_views DESC;
# --------
#
# Prompt:What is the average salary for employees who identify as female or non-binary, grouped by their department?
# --------
# SQL of res: ["SELECT Department, AVG(Salary) AS average_salary FROM Employees WHERE Gender IN ('Female', 'Non-binary') GROUP BY Department;"]
# SQL of truth: SELECT e.Department, AVG(e.Salary) as AvgSalary FROM Employees e WHERE e.Gender IN ('Female', 'Non-binary') GROUP BY e.Department;
# --------
#
# Prompt:What is the difference in average salary between employees who have and have not completed diversity and inclusion training, by job title and region?
# --------
# SQL of res: [None]
# SQL of truth: SELECT Region, JobTitle, AVG(CASE WHEN CompletedDiversityTraining THEN Salary ELSE NULL END) - AVG(CASE WHEN NOT CompletedDiversityTraining THEN Salary ELSE NULL END) AS Salary_Difference FROM Employees GROUP BY Region, JobTitle;
# --------
#
# Prompt:What is the average number of steals per game for the Lakers?
# --------
# SQL of res: ["SELECT AVG(gamesames.home_team_steals + games.away_team_steals) AS avg_steals_per_game FROM teams JOIN games ON team_id = games.home_team_id WHERE teams.team_name = 'Lakers';"]
# SQL of truth: SELECT AVG(home_team_steals + away_team_steals) as avg_steals FROM games WHERE home_team_id = (SELECT team_id FROM teams WHERE team_name = 'Lakers') OR away_team_id = (SELECT team_id FROM teams WHERE team_name = 'Lakers');
# --------
#
# Prompt:Which NFL team has the most Super Bowl titles?
# --------
# SQL of res: [None]
# SQL of truth: SELECT name FROM nfl_teams WHERE super_bowl_wins = (SELECT MAX(super_bowl_wins) FROM nfl_teams);
# --------
#
# Prompt:What is the total amount of funds allocated for each type of disaster?
# --------
# SQL of res: ['SELECT DisasterType, FORMAT(SUM(AllocatedAmount), 10.2) TotalFunds FROM DisasterFunds GROUP BY DisasterType;']
# SQL of truth: SELECT DisasterType, SUM(AllocatedAmount) as TotalFunds FROM DisasterFunds GROUP BY DisasterType;
# --------
#
# Prompt:Who is the contact person for the 'refugee support' sector?
# --------
# SQL of res: [None]
# SQL of truth: SELECT name, email FROM contacts WHERE sector = 'refugee support';
# --------
#
# Prompt:What is the total number of ethical AI projects in the healthcare sector?
# --------
# SQL of res: ["SELECT SUM(projects) AS total_projects FROM Ethical_AI WHERE sector = 'Healthcare';"]
# SQL of truth: SELECT sector, SUM(projects) FROM Ethical_AI WHERE sector = 'Healthcare';
# --------
#
# Prompt:Who are the top 3 suppliers of recycled polyester?
# --------
# SQL of res: ["SELECT name, COUNT(name, material) FROM suppliers WHERE material = 'Recycled Polyester' ORDER BY COUNT(name, material) DESC LIMIT 3;"]
# SQL of truth: SELECT name FROM suppliers WHERE material = 'Recycled Polyester' GROUP BY name ORDER BY COUNT(*) DESC LIMIT 3;
# --------
#
# Prompt:How many clients have taken out socially responsible loans in each country, excluding loans from clients in Saudi Arabia and the UAE?
# --------
# SQL of res: ["SELECT client_country, COUNT(*) AS loan_count FROM socially_responsible_loans WHERE client_country NOT IN ('Saudi Arabia', 'UAE') GROUP BY client_country"]
# SQL of truth: SELECT client_country, COUNT(DISTINCT client_id) as num_clients FROM socially_responsible_loans WHERE client_country NOT IN ('Saudi Arabia', 'UAE') GROUP BY client_country;
# --------
#
# Prompt:What is the total quantity of each product shipped from the Tokyo warehouse?
# --------
# SQL of res: ["SELECT s.ProductName, SUM(s.Quantity) AS total_quantity FROM Shipments s WHERE s.WarehouseID = 'WarehouseID' AND s.City='Tokyo' GROUP BY s.ProductName;"]
# SQL of truth: SELECT ProductName, SUM(Quantity) AS TotalQuantity FROM Shipments WHERE WarehouseID = 3 GROUP BY ProductName;
# --------
#
# Prompt:What is the number of traffic accidents in Toronto involving cyclists in the last 3 years, and how many resulted in injuries?
# --------
# SQL of res: [None]
# SQL of truth: SELECT COUNT(*) AS total_accidents, SUM(injury) AS injury_accidents FROM traffic_accidents WHERE location = 'Toronto' AND accident_type = 'cyclist' AND year BETWEEN 2019 AND 2021;
# --------
#
# Prompt:How many graduate students from underrepresented communities are enrolled in STEM programs?
# --------
# SQL of res: ["SELECT COUNT(*) AS Count FROM Students WHERE Community IN ('African American', 'Native American') AND Program IN ('Computer Science', 'Mathematics');"]
# SQL of truth: SELECT COUNT(*) FROM Students WHERE Program LIKE '%STEM%' AND Community IN ('African American', 'Hispanic', 'Native American')
# --------
#
# Prompt:What is the maximum grant amount awarded to any research project in the Chemistry department?
# --------
# SQL of res: ["SELECT MAX(amount) AS max_amount FROM grants WHERE department = 'Chemistry';"]
# SQL of truth: SELECT MAX(amount) FROM grants WHERE department = 'Chemistry';
# --------
#
# Prompt:List the top 3 countries with the most heritage sites and the number of sites for each?
# --------
# SQL of res: ['SELECT country, COUNT(site_id) AS number_of_sites FROM heritage_sites GROUP BY country ORDER BY number_of_sites DESC LIMIT 3;']
# SQL of truth: SELECT country, COUNT(*) AS num_sites FROM heritage_sites GROUP BY country ORDER BY num_sites DESC LIMIT 3;
# --------
#
# Prompt:How many species were observed per month in the Tundra Biology Study?
# --------
# SQL of res: ['SELECT year, month, SUM(species_observed) AS total_observed_species_per_month  FROM TundraBiologyStudy GROUP BY month;']
# SQL of truth: SELECT month, AVG(species_observed) FROM TundraBiologyStudy GROUP BY year, month HAVING AVG(species_observed) > 25;
# --------
#
# Prompt:How many traditional musicians are registered in Mexico?
# --------
# SQL of res: [None]
# SQL of truth: SELECT COUNT(*) FROM traditional_musicians WHERE country = 'Mexico';
# --------
#
# Prompt:Who are the top 3 contributors to heritage site preservation efforts in Africa?
# --------
# SQL of res: ["SELECT name, country, amount_donated FROM contributors WHERE country LIKE 'Africa%' ORDER BY amount_donated DESC LIMIT 3;"]
# SQL of truth: SELECT name FROM contributors ORDER BY amount_donated DESC LIMIT 3;
# --------
#
# Prompt:What is the count of bridges in California with seismic retrofit needs, categorized by bridge type and construction year?
# --------
# SQL of res: [None]
# SQL of truth: SELECT bridge_type, construction_year, COUNT(*) as count FROM Bridges WHERE state = 'CA' AND seismic_retrofit_need = TRUE GROUP BY bridge_type, construction_year;
# --------
#
# Prompt:What is the maximum resilience score for infrastructure projects in Texas?
# --------
# SQL of res: ["SELECT MAX(resilienceScore) AS maxResilienceScore FROM Infrastructure WHERE Location = 'Texas';"]
# SQL of truth: SELECT MAX(ResilienceScore) FROM Infrastructure WHERE Location = 'Texas';
# --------
#
# Prompt:Find the average carbon footprint of all 'sustainable_tourism' activities.
# --------
# SQL of res: ['SELECT AVG(carbon_footprint) AS average_carbon_footprint     FROM sustainable_tourism;']
# SQL of truth: SELECT AVG(carbon_footprint) FROM sustainable_tourism;
# --------
#
# Prompt:What is the average hotel rating for eco-friendly hotels in Japan?
# --------
# SQL of res: ["SELECT AVG(stars) AS average_rating     FROM hotels     WHERE country = 'Japan' AND is_eco_friendly = true;"]
# SQL of truth: SELECT AVG(stars) FROM hotels WHERE is_eco_friendly = true AND country = 'Japan';
# --------
#
# Prompt:What is the total number of marine mammals in the Gulf of Mexico, excluding dolphins and whales?
# --------
# SQL of res: [None]
# SQL of truth: SELECT SUM(count) FROM marine_mammals WHERE species NOT IN ('dolphin', 'whale') AND region = 'Gulf of Mexico';
# --------
#
# Prompt:What is the maximum monthly data usage for broadband subscribers in all regions?
# --------
# SQL of res: ['SELECT MAX(m.max_data_usage) AS monthly_max_data_usage FROM subscribers s JOIN maximum_usage m ON s.data_usage <= m.max_usage GROUP BY s.region, <sql>MAX(s.data_usage AS max_data_usage)']
# SQL of truth: SELECT MAX(data_usage) FROM subscribers;
# --------
#
# Prompt:What is the minimum data usage for mobile subscribers in Europe?
# --------
# SQL of res: ["SELECT MIN(data_usage) AS min_europe_data_usage FROM mobile_subscribers  WHERE continent = 'Europe';"]
# SQL of truth: SELECT MIN(data_usage) FROM mobile_subscribers WHERE continent = 'Europe';
# --------
#
# Prompt:What is the conservation status of the 'Giant Pacific Octopus'?
# --------
# SQL of res: ["SELECT conservation_status FROM species WHERE (scientific_name = 'Giant Pacific Octopus'  AND common_name = 'Giant Pacific Octopus');"]
# SQL of truth: SELECT conservation_status FROM species WHERE common_name = 'Giant Pacific Octopus';
# --------
#
# Prompt:Which countries have the highest and lowest ocean acidity levels?
# --------
# SQL of res: ['SELECT avg_ph FROM country      WHERE avg_ph = ( SELECT avg_ph FROM country WHERE avg_ph = ( SELECT avg_ph     FROM country ));']
# SQL of truth: SELECT country, avg_ph FROM (SELECT country, avg_ph, ROW_NUMBER() OVER (ORDER BY avg_ph DESC) as rnk FROM ocean_acidity) subq WHERE rnk = 1 OR rnk = (SELECT COUNT(*) FROM ocean_acidity) ORDER BY avg_ph;
# --------
#
# Prompt:List the donation amounts and dates for donations made by the donor with ID = 2, in descending order by date.
# --------
# SQL of res: ['SELECT   column1.DonationDate AS DonationDate,   column1.DonationAmount AS DonationAmount   FROM Donations WHERE   column1.DonorID = 2 ORDER BY   DonationDate DESC;']
# SQL of truth: SELECT DonationAmount, DonationDate FROM Donations WHERE DonorID = 2 ORDER BY DonationDate DESC;
# --------

# %%
print(complexity_eval_res)
# Out:
# {'basic SQL': {'err_res': 552, 'correct': 0, 'parsable': 0, 'total': 552, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 915.000001}, 'aggregation': {'err_res': 225, 'correct': 0, 'parsable': 0, 'total': 225, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1229.0000009999999}, 'window functions': {'err_res': 30, 'correct': 0, 'parsable': 0, 'total': 30, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 278.000001}, 'single join': {'err_res': 122, 'correct': 0, 'parsable': 0, 'total': 122, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 412.000001}, 'multiple_joins': {'err_res': 18, 'correct': 0, 'parsable': 0, 'total': 18, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 60.000001}, 'subqueries': {'err_res': 46, 'correct': 0, 'parsable': 0, 'total': 46, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 109.000001}, 'set operations': {'err_res': 7, 'correct': 0, 'parsable': 0, 'total': 7, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 28.000001}}

# %%
scores_by_complexity = {}

for complexity, counts in complexity_eval_res.items():
    print(f"Complexity: {complexity}, num. samples = {counts['total']}")
    print(f"   Macro stats -- correct:{counts['correct']/counts['total']:.2} | parsable: {counts['parsable']/counts['total']:.2}")
    precision = counts['cell_intersect']/counts['cell_predict']
    recall = counts['cell_intersect']/counts['cell_gold']
    print(f"   Cell stats -- precision:{precision:.2} | recall:{recall:.2} | F1: {(2 * precision * recall) / (precision + recall+1e-9)}")
    
    scores_by_complexity[complexity] = {
        "accuracy": counts['correct']/counts['total'],
        "parsable": counts['parsable']/counts['total'],
        "precision": precision,
        "recall": recall,
        "f1": (2 * precision * recall) / (precision + recall+1e-9)
    }
    # precision = intersection_count / total_predicted
    #recall = intersection_count / total_gold

# Overall stats
overall_counts = {"correct":0, "parsable":0, "total":0, "cell_intersect":0, "cell_predict":0.000001, "cell_gold": 0.000001}
for complexity, counts in complexity_eval_res.items():
    overall_counts['correct'] += counts['correct']
    overall_counts['parsable'] += counts['parsable']
    overall_counts['total'] += counts['total']
    overall_counts['cell_intersect'] += counts['cell_intersect']
    overall_counts['cell_predict'] += counts['cell_predict']
    overall_counts['cell_gold'] += counts['cell_gold']
# print(f"Overall Complexity: num. samples = {overall_counts['total']}")
# print(f"   Micro stats -- correct:{overall_counts['correct']/overall_counts['total']:.2} | parsable: {overall_counts['parsable']/overall_counts['total']:.2}")
# precision = overall_counts['cell_intersect']/overall_counts['cell_predict']
# recall = overall_counts['cell_intersect']/overall_counts['cell_gold']
# print(f"   Cell stats -- precision:{precision:.2} | recall:{recall:.2} | F1: {(2 * precision * recall) / (precision + recall+1e-9)}")
print("*" * 100)
print("Micro-averaged scores:")
micro_accuracy = overall_counts['correct']/overall_counts['total']
micro_parsable = overall_counts['parsable']/overall_counts['total']
micro_precision = overall_counts['cell_intersect']/overall_counts['cell_predict']
micro_recall = overall_counts['cell_intersect']/overall_counts['cell_gold']
micro_f1 = (2 * micro_precision * micro_recall) / (micro_precision + micro_recall+1e-9)
print(f"   Micro Accuracy: {micro_accuracy:.2}")
print(f"   Micro Parsable: {micro_parsable:.2}")
print(f"   Micro Precision: {micro_precision:.2}")
print(f"   Micro Recall: {micro_recall:.2}")


print("*" * 100)
# Macro accuracy, precision, recall and F1 can be calculated by averaging the values across complexities
print("Macro-averaged scores:")
macro_accuracy = sum([scores_by_complexity[comp]['accuracy'] for comp in scores_by_complexity]) / len(scores_by_complexity)
macro_parsable = sum([scores_by_complexity[comp]['parsable'] for comp in scores_by_complexity]) / len(scores_by_complexity)
macro_precision = sum([scores_by_complexity[comp]['precision'] for comp in scores_by_complexity]) / len(scores_by_complexity)
macro_recall = sum([scores_by_complexity[comp]['recall'] for comp in scores_by_complexity]) / len(scores_by_complexity)
macro_f1 = sum([scores_by_complexity[comp]['f1'] for comp in scores_by_complexity]) / len(scores_by_complexity)
print(f"   Macro Accuracy: {macro_accuracy:.2}")
print(f"   Macro Parsable: {macro_parsable:.2}")
print(f"   Macro Precision: {macro_precision:.2}")
print(f"   Macro Recall: {macro_recall:.2}")
# Out:
# Complexity: basic SQL, num. samples = 552
#    Macro stats -- correct:0.0 | parsable: 0.0
#    Cell stats -- precision:0.0 | recall:0.0 | F1: 0.0
# Complexity: aggregation, num. samples = 225
#    Macro stats -- correct:0.0 | parsable: 0.0
#    Cell stats -- precision:0.0 | recall:0.0 | F1: 0.0
# Complexity: window functions, num. samples = 30
#    Macro stats -- correct:0.0 | parsable: 0.0
#    Cell stats -- precision:0.0 | recall:0.0 | F1: 0.0
# Complexity: single join, num. samples = 122
#    Macro stats -- correct:0.0 | parsable: 0.0
#    Cell stats -- precision:0.0 | recall:0.0 | F1: 0.0
# Complexity: multiple_joins, num. samples = 18
#    Macro stats -- correct:0.0 | parsable: 0.0
#    Cell stats -- precision:0.0 | recall:0.0 | F1: 0.0
# Complexity: subqueries, num. samples = 46
#    Macro stats -- correct:0.0 | parsable: 0.0
#    Cell stats -- precision:0.0 | recall:0.0 | F1: 0.0
# Complexity: set operations, num. samples = 7
#    Macro stats -- correct:0.0 | parsable: 0.0
#    Cell stats -- precision:0.0 | recall:0.0 | F1: 0.0
# ****************************************************************************************************
# Micro-averaged scores:
#    Micro Accuracy: 0.0
#    Micro Parsable: 0.0
#    Micro Precision: 0.0
#    Micro Recall: 0.0
# ****************************************************************************************************
# Macro-averaged scores:
#    Macro Accuracy: 0.0
#    Macro Parsable: 0.0
#    Macro Precision: 0.0
#    Macro Recall: 0.0
