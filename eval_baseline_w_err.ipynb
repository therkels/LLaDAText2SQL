# %% [markdown]
# ## Setup imports

# %%
import csv
import pandas as pd
from datasets import load_dataset
from database_interface import DatabaseHelper
from collections import Counter
# MODEL_OUTPUT_PATH = "/scratch/eecs595f25_class_root/eecs595f25_class/llada_data/synthetic_text_to_sql/output_sql.csv"
# MODEL_OUTPUT_PATH = "./eval.csv"
# MODEL_OUTPUT_PATH = "/scratch/eecs595f25_class_root/eecs595f25_class/llada_data/eval_results_ar.csv"
# MODEL_OUTPUT_PATH = "/scratch/eecs595f25_class_root/eecs595f25_class/llada_data/masking_only_res.csv"
MODEL_OUTPUT_PATH = "/scratch/eecs595f25_class_root/eecs595f25_class/llada_data/masking_and_gen_pred_res.csv"
# MODEL_OUTPUT_PATH = "/scratch/eecs595f25_class_root/eecs595f25_class/llada_data/baseline.csv"
OUTPUT_FILE_PATH = "/scratch/eecs595f25_class_root/eecs595f25_class/llada_data/synthetic_text_to_sql/valid_test.json"

# %% [markdown]
# ## Load in initial dataset

# %%
retrieved_dataset = load_dataset("json", data_files=OUTPUT_FILE_PATH)["train"]
print(f"retrieved dataset, info={retrieved_dataset}")
# Out:
# retrieved dataset, info=Dataset({
#     features: ['id', 'domain', 'domain_description', 'sql_complexity', 'sql_complexity_description', 'sql_task_type', 'sql_task_type_description', 'sql_prompt', 'sql_context', 'sql', 'sql_explanation'],
#     num_rows: 3434
# })

# %% [markdown]
# ## Load and merge the results with the examples

# %%
model_res_df = pd.read_csv(MODEL_OUTPUT_PATH)
print(len(model_res_df))
gold_standard_df = retrieved_dataset.to_pandas()
gold_standard_df = gold_standard_df.iloc[0:len(model_res_df)][[
    'id',
    'sql_complexity',
    'sql',
    'sql_context',
    'sql_prompt',
    'sql_explanation'
    
]]

eval_df = pd.merge(model_res_df, gold_standard_df,on='id')[:701]
# print(eval_df)
print(eval_df)
# Out:
# 1101
#        id                                            out_sql  time_taken  \
# 0       1  ["SELECT AVG(explainability_score) AS average_...   14.568391
# 1       3                                             [None]   12.825452
# 2       4  ['SELECT location, quantity,  price AS price_s...   11.670998
# 3       5  ['SELECT (\n    SELECT SUM(budget) AS total_bu...   13.743944
# 4       7  ['SELECT plant_name, chemical_name, co2_emissi...   14.048213
# ..    ...                                                ...         ...
# 696  1183  ["SELECT AVG(visitors) AS average_visitors \nF...   11.076334
# 697  1184                                             [None]   11.614414
# 698  1188                                             [None]    8.144133
# 699  1189  ["SELECT id, name, (1 - depleted_resources / t...   13.250320
# 700  1190  ['SELECT city, COUNT(*) AS donation_count \nFR...   11.772388
#
#     sql_complexity                                                sql  \
# 0        basic SQL  SELECT AVG(explainability_score) FROM creative...
# 1      aggregation  SELECT launch_provider, COUNT(*) FROM Accident...
# 2        basic SQL                   SELECT MAX(quantity) FROM sales;
# 3        basic SQL  SELECT SUM(budget) FROM Movies_Release_Year WH...
# 4      aggregation  SELECT plant_name, SUM(co2_emission_per_ton_pr...
# ..             ...                                                ...
# 696      basic SQL  SELECT AVG(visitors) FROM antarctica_attractions;
# 697    aggregation  SELECT disputes.type, disputes.resolution_meth...
# 698      basic SQL  SELECT MAX(max_servings) FROM side_dishes WHER...
# 699      basic SQL  SELECT name, (depleted_resources * 100.0 / tot...
# 700    aggregation  SELECT city, COUNT(*) as total_donations FROM ...
#
#                                            sql_context  \
# 0    CREATE TABLE creative_ai (application_id INT, ...
# 1    CREATE TABLE Accidents (id INT, launch_provide...
# 2    CREATE TABLE sales (id INT, location VARCHAR(2...
# 3    CREATE TABLE Movies_Release_Year (id INT, titl...
# 4    CREATE TABLE co2_emissions (id INT PRIMARY KEY...
# ..                                                 ...
# 696  CREATE TABLE antarctica_attractions (id INT, n...
# 697  CREATE TABLE disputes (dispute_id INT, type VA...
# 698  CREATE TABLE side_dishes (id INT, side_name TE...
# 699  CREATE TABLE mines (id INT, name VARCHAR(50), ...
# 700  CREATE TABLE donations_2 (id INT PRIMARY KEY, ...
#
#                                             sql_prompt  \
# 0    What is the average explainability score of cr...
# 1    How many accidents have been recorded for Spac...
# 2    What is the maximum quantity of seafood sold i...
# 3    What is the total budget for movies released b...
# 4    Identify the top 2 plants with the highest CO2...
# ..                                                 ...
# 696  Find the average visitor count for natural att...
# 697  What is the success rate of alternative disput...
# 698  What is the maximum number of servings of any ...
# 699  What's the percentage of coal resources deplet...
# 700         How many donations were made in each city?
#
#                                        sql_explanation
# 0    This SQL query calculates the average explaina...
# 1    This query groups the Accidents table by the l...
# 2    Find the maximum quantity of seafood sold in a...
# 3    This query calculates the total budget for mov...
# 4    This query calculates the total CO2 emissions ...
# ..                                                 ...
# 696  This SQL query calculates the average visitor ...
# 697  This query calculates the success rate of alte...
# 698  The SQL query filters the side_dishes table to...
# 699  This query calculates the percentage of coal r...
# 700  Count the number of donations made in each cit...
#
# [701 rows x 8 columns]

# %% [markdown]
# ## Setup Bag-of-cells to do analysis of each data cell in outputs (Gemini provided)

# %%
def get_cell_counts(df_gold, df_predicted):
    """
    Calculates Precision, Recall, and F1 score based on a 
    "Bag of Cells" (multiset of all values).
    """
    
    # --- 1. Flatten Gold DataFrame into a Counter ---
    # .values.flatten() turns the whole DF into a 1D numpy array
    # We must handle potential 'None' values which Counter might not like
    gold_cells = Counter([str(v) for v in df_gold.values.flatten() if v is not None])
    
    # --- 2. Flatten Predicted DataFrame into a Counter ---
    predicted_cells = Counter([str(v) for v in df_predicted.values.flatten() if v is not None])

    # --- 3. Calculate Scores ---
    
    # Handle the "divide by zero" case if no cells are returned
    total_gold = sum(gold_cells.values())
    total_predicted = sum(predicted_cells.values())

    # & (intersection) finds the element-wise minimum
    intersection = gold_cells & predicted_cells
    intersection_count = sum(intersection.values())
    
    # precision = intersection_count / total_predicted
    # recall = intersection_count / total_gold
        
    return intersection_count, total_predicted, total_gold


#test
df_gold_1 = pd.DataFrame([[1.0, 2000.0], [1.0, 2000.0], [2.0, 4000.0], [2.0, 4000.0]])
df_pred_1 = pd.DataFrame([[1.0, 2000.0], [2.0, 4000.0]])
p, r, f1 = get_cell_counts(df_gold_1, df_pred_1)
print(f"Example 1 F1: {f1:.2f} (P={p:.2f}, R={r:.2f})")


df_gold_2 = pd.DataFrame([['Commercial', 70.0]])
df_pred_2 = pd.DataFrame([[70.0]])
p, r, f1 = get_cell_counts(df_gold_2, df_pred_2)
print(f"Example 2 F1: {f1:.2f} (P={p:.2f}, R={r:.2f})")
# Out:
# Example 1 F1: 8.00 (P=4.00, R=4.00)
# Example 2 F1: 2.00 (P=1.00, R=1.00)

# %% [markdown]
# ## Iterate over examples and process the results!

# %%
sql_difficulty = eval_df['sql_complexity'].unique()
complexity_eval_res = {complexity:{"err_res":0, "correct":0, "parsable":0, "total":0, "cell_intersect":0, "cell_predict":0.000001, "cell_gold": 0.000001} for complexity in sql_difficulty}
print(complexity_eval_res)
count = 0
for index, row in eval_df.iterrows():
    # comment this out and use below line if measuring AR model...This is hacky but works
    model_sql_res = row.out_sql[1:len(row.out_sql)-1]
    # model_sql_res = row.out_sql
    complexity = row.sql_complexity
    complexity_eval_res[complexity]['total'] += 1
    if model_sql_res != "None":
        db_obj = DatabaseHelper(":memory:")
        db_obj.insert_data(row.sql_context)
        # Do minimal cleaning to pass the SQL
        cleaned_sql = model_sql_res.strip().strip("'").replace("\\n"," ").strip("\"")
        model_res, status = db_obj.fetch_data(cleaned_sql)
        
        if status != "failure":
            complexity_eval_res[complexity]['parsable'] += 1
        else:
            complexity_eval_res[complexity]['err_res'] += 1
            print(f"Prompt:{row.sql_prompt}")
            print("--------")
            print(f"SQL of res: {cleaned_sql}")
            print(f"SQL of truth: {row.sql}")
            print("--------")
            print()
        
            
        # If SQL parsed, increment score
        # complexity_eval_res[complexity]['parsable'] += 1
#         if model_res.empty:
#             # print(f"ID:{index} -- SQL that caused error:\n{model_sql_res}\n")
#             continue
            
        truth_res, status = db_obj.fetch_data(row.sql)
        # try:
        model_res_normalized = Counter(
            [tuple(sorted(row, key=str)) for row in model_res.values.tolist()]
        )
        truth_res_normalized = Counter(
            [tuple(sorted(row, key=str)) for row in truth_res.values.tolist()]
        )
        # except Exception as e:
        #     print("PARSING ISSUE")
        #     print(e)
        #     print("DATA:")
        #     print(truth_res)
        #     print(model_res)
        # if model_res_normalized != truth_res_normalized and complexity == "subqueries":
        #     print(f"DEBUG:\n Model res:\n{model_res_normalized}\nTruth res:\n{truth_res_normalized}\n")
        #     print(f"Prompt:{row.sql_prompt}")
        #     print(f"SQL of res: {cleaned_sql}")
        #     print(f"SQL of truth: {row.sql}")
        #     print(f"SQL explanation: {row.sql_explanation}")
        #     print("---------")
        # Give correct point for results that are matched
        # Note: This is a naive method which doesn't consider ORDER by. We will assume the non-ordered data considered 'correct'
        
        complexity_eval_res[complexity]['correct'] += 1 if model_res_normalized == truth_res_normalized else 0
        # get cell matches
        intersect_count, predict_count, gold_count = get_cell_counts(truth_res, model_res)
    
        # if complexity == "subqueries":
        #     print("MODEL RES")
        #     print(model_res)
        #     print("TRUTH RES")
        #     print(truth_res)
        #     print(get_cell_counts(truth_res, model_res))
        #     count += 1
        #     print("number of subqueires considered:",count)
        complexity_eval_res[complexity]['cell_intersect'] += intersect_count
        complexity_eval_res[complexity]['cell_predict'] += predict_count
        complexity_eval_res[complexity]['cell_gold'] += gold_count
# Out:
# {'basic SQL': {'err_res': 0, 'correct': 0, 'parsable': 0, 'total': 0, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1e-06}, 'aggregation': {'err_res': 0, 'correct': 0, 'parsable': 0, 'total': 0, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1e-06}, 'window functions': {'err_res': 0, 'correct': 0, 'parsable': 0, 'total': 0, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1e-06}, 'single join': {'err_res': 0, 'correct': 0, 'parsable': 0, 'total': 0, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1e-06}, 'multiple_joins': {'err_res': 0, 'correct': 0, 'parsable': 0, 'total': 0, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1e-06}, 'subqueries': {'err_res': 0, 'correct': 0, 'parsable': 0, 'total': 0, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1e-06}, 'set operations': {'err_res': 0, 'correct': 0, 'parsable': 0, 'total': 0, 'cell_intersect': 0, 'cell_predict': 1e-06, 'cell_gold': 1e-06}}
# Prompt:What is the maximum quantity of seafood sold in a single transaction?
# --------
# SQL of res: SELECT location, quantity,  price AS price_sold FROM sales WHERE (  quantity * price ) = ( SELECT MAX quantity * price AS price_sold ) FROM sales );
# SQL of truth: SELECT MAX(quantity) FROM sales;
# --------
#
# Prompt:What is the average number of publications per researcher for researchers working at the 'National Geographic' organization?
# --------
# SQL of res: SELECT AVG(pubs_count) AS average_pubs_per_res FROM researchers WHERE organization = 'National Geographic' AND (id NOT IN (SELECT COUNT(*) FROM researchers));
# SQL of truth: SELECT organization, AVG(publications) as avg_publications FROM researchers WHERE organization = 'National Geographic';
# --------
#
# Prompt:What is the average number of military personnel per country involved in peacekeeping operations?
# --------
# SQL of res: SELECT AVG(military_personnel) AS average_military FROM (SELECT country FROM Peacekeeping_Operations GROUP BY country) AS country_personnel GROUP BY country;
# SQL of truth: SELECT AVG(military_personnel) FROM Peacekeeping_Operations;
# --------
#
# Prompt:What is the total amount donated to each program?
# --------
# SQL of res: SELECT ProgramName, SUM(DonationAmount) AS TotalAmount     FROM Donations INNER JOIN DonorsPrograms ON DonorID = DonorID ON LEFT JOIN Programs ON ProgramID = ProgramID ON     GROUP BY ProgramName;
# SQL of truth: SELECT Programs.ProgramName, SUM(Donations.DonationAmount) AS TotalDonatedAmount FROM Programs INNER JOIN DonorsPrograms ON Programs.ProgramID = DonorsPrograms.ProgramID INNER JOIN Donations ON DonorsPrograms.DonorID = Donations.DonorID GROUP BY Programs.ProgramName;
# --------
#
# Prompt:What is the average number of visitor reviews for heritage sites in each category?
# --------
# SQL of res: SELECT Category, AVG(Review) AS AverageReviews     FROM HeritageSitesReviews     GROUP BY Category;
# SQL of truth: SELECT Category, AVG(Reviews) OVER (PARTITION BY Category) AS AvgReviews FROM HeritageSitesReviews;
# --------
#
# Prompt:What is the distribution of language preservation initiatives by initiative type?
# --------
# SQL of res: SELECT initiative AS initiative_type, COUNT(*) OVER initiative_type initiative AS initiative_count  FROM language_preservation_by_initiative  GROUP BY initiative  ORDER BY initiative_count DESC;
# SQL of truth: SELECT initiative, initiative_count FROM language_preservation_by_initiative;
# --------
#
# Prompt:What is the number of patients in India who received group therapy?
# --------
# SQL of res: SELECT COUNT(DISTINCT p) AS number_of_patients_in_india FROM patients p LEFT JOIN treatments t ON p.id = t.patient_id WHERE p.country = 'India' AND t.treatment = 'Group Therapy';
# SQL of truth: SELECT COUNT(*) FROM patients INNER JOIN treatments ON patients.id = treatments.patient_id WHERE treatments.treatment = 'Group Therapy' AND patients.country = 'India';
# --------
#
# Prompt:What is the total biomass of marine species in ascending order of depth?
# --------
# SQL of res: SELECT SUM(biomass) AS total, type FROM ( SELECT type, species  FROM biomass  WHERE species = 'marine species' ) ORDER BY type ASC;
# SQL of truth: SELECT type, SUM(biomass) total_biomass FROM biomass GROUP BY type ORDER BY total_biomass ASC;
# --------
#
# Prompt:What is the average rating of movies by director in the Media database?
# --------
# SQL of res: SELECT (     SELECT Director, AVG(Rating) AS AverageRating     FROM DirectorMoviesRating     GROUP BY Director ) AS Director AS DirectorAverageRating;
# SQL of truth: SELECT Director, AVG(Rating) as AverageRating FROM DirectorMoviesRating GROUP BY Director;
# --------
#
# Prompt:What is the change in housing affordability in Portland from Q1 2021 to Q2 2021?
# --------
# SQL of res: SELECT affordability2 - affordability1 AS change_in_affordability FROM (SELECT affordability AS affordability1 FROM portland_housing WHERE year = 2021);
# SQL of truth: SELECT (MAX(affordability) FILTER (WHERE year = 2021 AND quarter = 2) - MAX(affordability) FILTER (WHERE year = 2021 AND quarter = 1)) FROM portland_housing;
# --------
#
# Prompt:What is the difference in the total quantity of products sold in the 'apparel' category between this year and last year?
# --------
# SQL of res: SELECT (SELECT SUM(quantity) FROM sales WHERE product_category = 'Apparel' AND year = CURRENT YEAR) - (SELECT SUM(quantity) FROM sales WHERE product_category = 'Apparel' AND year = LAST YEAR) AS quantity_difference;
# SQL of truth: SELECT product_category, (SUM(CASE WHEN year = 2022 THEN quantity ELSE 0 END) - SUM(CASE WHEN year = 2021 THEN quantity ELSE 0 END)) as quantity_diff FROM sales WHERE product_category = 'Apparel' GROUP BY product_category;
# --------
#
# Prompt:What is the count of vessels that have visited a specific port in a given month?
# --------
# SQL of res: SELECT COUNT(*) AS vessel_count FROM Vessels v JOIN PortCalls pc ON v.id = pc.vesel_id WHERE pc.port = 'PortA' AND pc.call_date = DATE('2021-03-01');
# SQL of truth: SELECT COUNT(PortCalls.id) FROM PortCalls WHERE PortCalls.port = 'PortA' AND PortCalls.call_date >= '2021-03-01' AND PortCalls.call_date <= '2021-03-31';
# --------
#
# Prompt:What is the average landfill tipping fee for each region?
# --------
# SQL of res: SELECT R.region, AVG(L.tipping_fee) AS average_tipping_fee FROM Region R INNER JOIN Landfill_All L ON R.region = L.region GROUP BY R.region;
# SQL of truth: SELECT region, AVG(tipping_fee) FROM Landfill_All GROUP BY region;
# --------
#
# Prompt:What is the ratio of successful community education programs to total programs for each country, ordered by the success rate in descending order?
# --------
# SQL of res: SELECT Country, (CASE WHEN Success THEN 1 END) / Programs) AS SuccessRate FROM CountryPrograms     GROUP BY Country ORDER BY SuccessRate DESC
# SQL of truth: SELECT Country, COUNT(*) FILTER (WHERE Success) * 1.0 / COUNT(*) as SuccessRate FROM CountryPrograms GROUP BY Country ORDER BY SuccessRate DESC;
# --------
#
# Prompt:Which defense contracts have the highest total value, and what are their respective values?
# --------
# SQL of res: SELECT Contract_Name, Agency, Value FROM Defense_Contracts WHERE Value = (SELECT Value DESC FROM (SELECT ORDER BY Value DESC FROM Defense_Contracts LIMIT 1) );
# SQL of truth: SELECT Contract_Name, Value FROM (SELECT Contract_Name, Value, ROW_NUMBER() OVER (ORDER BY Value DESC) as Rank FROM Defense_Contracts) as Ranked_Contracts WHERE Rank <= 3;
# --------
#
# Prompt:Which sustainable materials are used by companies in the 'Asia-Pacific' region?
# --------
# SQL of res: SELECT c.name AS company_name, m.material AS material_type, m.quantity AS quantity FROM Companies AS c JOIN Materials AS m ON m.company_id = c.id WHERE c.region_Lower() = 'asia-Pacific';
# SQL of truth: SELECT DISTINCT Materials.material FROM Companies JOIN Materials ON Companies.id = Materials.company_id WHERE Companies.region = 'Asia-Pacific';
# --------
#
# Prompt:What is the average renewable energy capacity per project in each country?
# --------
# SQL of res: SELECT country, AVG(project_capacity) AS average_capacity FROM renewable_energy_projects GROUP BY country;
# SQL of truth: SELECT project_name, country, capacity, AVG(capacity) OVER (PARTITION BY country) AS avg_capacity FROM renewable_energy_projects;
# --------
#
# Prompt:How many movies were released each year?
# --------
# SQL of res: SELECT release_year AS release_year, COUNT(*) AS movie_count FROM movies GROUP BY release_year AS release_year ORDER BY release_year AS release_year;
# SQL of truth: SELECT release_year, COUNT(*) FROM movies GROUP BY release_year;
# --------
#
# Prompt:What are the top 3 countries with the most rare earth element production?
# --------
# SQL of res: SELECT country, production FROM production; SELECT country, production FROM production WHERE country NOT IN production UNION SELECT country, production FROM production ORDER BY production DESC LIMIT 3;
# SQL of truth: SELECT country FROM production ORDER BY production DESC LIMIT 3;
# --------
#
# Prompt:What is the obesity rate among adults in North American countries in 2019?
# --------
# SQL of res: SELECT SUM(ObesityRate FROM ObesityRates WHERE Continent = 'North America' AND Year = 2019 AND Country IN ('Canada', 'Mexico'));
# SQL of truth: SELECT Country, Continent, ObesityRate FROM ObesityRates WHERE Continent = 'North America' AND Year = 2019;
# --------
#
# Prompt:What is the difference in total points scored between the home and away games for each team in the 2020 baseball season?
# --------
# SQL of res: SELECT (     SELECT team_id, team_name, (points_home - points_away) AS points_difference     FROM baseball_season ) AS team_diff;
# SQL of truth: SELECT team_name, (points_home - points_away) as diff FROM baseball_season;
# --------
#
# Prompt:What is the total number of traditional art pieces created in each region with a population greater than 500,000?
# --------
# SQL of res: SELECT name, SUM(CASE type = 'Traditional') AS total FROM regions CROSS JOIN art_pieces WHERE name AND population > 500000;
# SQL of truth: SELECT r.name, COUNT(ap.id) FROM regions r JOIN art_pieces ap ON r.id = ap.region_id WHERE r.population > 500000 GROUP BY r.id;
# --------
#
# Prompt:Which mental health conditions were treated most frequently in Canada during 2022?
# --------
# SQL of res: SELECT condition, COUNT(*) AS condition_count FROM treatments t INNER JOIN conditions c ON tatient_id = c.patient_id WHERE country = 'Canada' AND treatment_date = YEAR(treatment_date) GROUP BY condition ORDER BY condition_count DESC;
# SQL of truth: SELECT conditions.condition, COUNT(conditions.condition) AS count FROM conditions JOIN patients ON conditions.patient_id = patients.id JOIN treatments ON patients.id = treatments.patient_id WHERE patients.country = 'Canada' AND treatments.treatment_date >= '2022-01-01' AND treatments.treatment_date < '2023-01-01' GROUP BY conditions.condition ORDER BY count DESC LIMIT 1;
# --------
#
# Prompt:How many mobile subscribers are there in each region?
# --------
# SQL of res: SELECT * FROM (SELECT region, COUNT(*) AS subscribers FROM mobile_subscribers  GROUP BY region) AS region_counts UNION SELECT region, COUNT(*) AS subscribers FROM region_counts;
# SQL of truth: SELECT region, COUNT(*) FROM mobile_subscribers GROUP BY region;
# --------
#
# Prompt:Identify the number of unique causes supported by volunteers from different countries.
# --------
# SQL of res: SELECT COUNT(*) AS causes, COUNT(*) AS num_causes FROM volunteers GROUP BY country GROUP BY COUNT(*) ORDER BY num_causes DESC;
# SQL of truth: SELECT country, COUNT(DISTINCT cause) as unique_causes FROM volunteers GROUP BY country;
# --------
#
# Prompt:What is the average capacity of renewable energy projects for each country?
# --------
# SQL of res: SELECT country, AVG(capacity) AS FROM (SELECT country, type FROM projects WHERE type IN ('Wind', 'Solar') GROUP BY country, type) AS projects;
# SQL of truth: SELECT country, AVG(capacity) FROM projects GROUP BY country
# --------
#
# Prompt:What is the average water consumption per capita in Tokyo and Seoul for the year 2019?
# --------
# SQL of res: SELECT AVG((water_consumption) / population) AS average_water_per_cita  FROM asia_population JOIN asia_water_consumption WHERE city IN ('Tokyo', 'Seoul') AND year = 2019;
# SQL of truth: SELECT AVG(awc.water_consumption / ap.population) FROM asia_water_consumption awc INNER JOIN asia_population ap ON awc.city = ap.city WHERE awc.year = 2019;
# --------
#
# Prompt:What is the total water consumption in liters for residential users in July 2021?
# --------
# SQL of res: SELECT SUM(consumption) AS total FROM water_consumption WHERE user_category = residential AND usage_date = '2021-07-01';
# SQL of truth: SELECT SUM(consumption) FROM water_consumption WHERE user_category = 'residential' AND usage_date >= '2021-07-01' AND usage_date <= '2021-07-31';
# --------
#
# Prompt:How many cases did attorney 'Jane Doe' handle in total?
# --------
# SQL of res: SELECT COUNT(c.CaseID) AS total_cases_handled FROM Cases c LEFT JOIN Attorneys a ON c.AttorneyID = a.A.AttorneyID WHERE a.Name = 'Jane Doe' AND (Category = 'Civil' OR Category IS NULL)
# SQL of truth: SELECT COUNT(*) as TotalCases FROM Cases WHERE AttorneyID = (SELECT AttorneyID FROM Attorneys WHERE Name = 'Jane Doe');
# --------
#
# Prompt:Which countries received shipments of Chemical E in the last 3 months?
# --------
# SQL of res: SELECT DISTINCT shipped_to FROM shipments WHERE product = 'Chemical E'   AND shipped_date >= CURRENT_DATE - INTERVAL '3 months'    AND shipped_date < CURRENT_DATE - INTERVAL '3 months';
# SQL of truth: SELECT DISTINCT shipped_to FROM shipments WHERE product = 'Chemical E' AND shipped_date >= '2022-04-01'
# --------
#
# Prompt:Identify the most frequently purchased beauty product by customers from the US.
# --------
# SQL of res: SELECT product_name, COUNT(*) AS purchase_count FROM customer_purchases WHERE country = 'US' OR country = 'CA' AND ( OR product_name LIKE '%') GROUP BY product_name ORDER BY purchase_count DESC LIMIT 1;
# SQL of truth: SELECT product_name, COUNT(*) as purchase_count FROM customer_purchases WHERE country = 'US' GROUP BY product_name ORDER BY purchase_count DESC LIMIT 1;
# --------
#
# Prompt:What is the production count for well 'A01' in the 'Gulf of Mexico'?
# --------
# SQL of res: SELECT well_id AS well_id,         production_count AS production_count    FROM wells w    JOIN production p ON w.well_id = p.well_id   WHERE w.well_location = 'Gulf of Mexico';
# SQL of truth: SELECT production_count FROM production WHERE well_id = 'A01';
# --------
#
# Prompt:How many organizations provide 'food_support' in 'refugee_camps' and 'disaster_zones'?
# --------
# SQL of res: SELECT COUNT(*) AS num_orgs FROM (SELECT FROM refugee_camps WHERE services = 'food_support' OR SELECT FROM disaster_zones WHERE services = 'food_support');
# SQL of truth: SELECT SUM(num_orgs) FROM refugee_camps WHERE services LIKE '%food_support%' UNION SELECT SUM(num_orgs) FROM disaster_zones WHERE services LIKE '%food_support%';
# --------
#
# Prompt:How many solar power projects were completed in California since 2015 with a budget over $5 million?
# --------
# SQL of res: SELECT COUNT(*) FROM projects WHERE state = 'California' AND year_completed > 2015 AND budget > 5M AND project_type = 'Solar';
# SQL of truth: SELECT COUNT(*) FROM projects WHERE state = 'California' AND year_completed >= 2015 AND project_type = 'Solar' AND budget > 5000000;
# --------
#
# Prompt:What are the total copper exports and CO2 emissions from Chile between 2016 and 2018?
# --------
# SQL of res: SELECT SUM(export_amount) AS chile_copper_export_total, SUM( emission ) AS chile_co2_emission_total FROM chile_co2_emission WHERE year BETWEEN 2016 AND 2018  ;
# SQL of truth: SELECT SUM(chile_copper_export.export_amount), SUM(chile_co2_emission.emission) FROM chile_copper_export INNER JOIN chile_co2_emission ON chile_copper_export.year = chile_co2_emission.year WHERE chile_copper_export.year BETWEEN 2016 AND 2018;
# --------
#
# Prompt:What is the total number of broadband customers and the total connection speed in Mbps for each region in 2021?
# --------
# SQL of res: SELECT region AS region,            COUNT(*) AS total_customers,            SUM(connection_speed) AS total_speed  FROM speeds WHERE service = 'broadband' AND year = 2021  GROUP BY region;
# SQL of truth: SELECT subscribers.region, COUNT(subscribers.id) AS total_customers, SUM(speeds.connection_speed) AS total_speed FROM subscribers JOIN speeds ON subscribers.id = speeds.subscriber_id WHERE subscribers.service = 'broadband' AND speeds.year = 2021 GROUP BY subscribers.region;
# --------
#
# Prompt:What is the total budget allocated for disability support programs in the year 2025, ordered by the amount of budget allocated?
# --------
# SQL of res: SELECT Year, SUM(Budget) AS (  ( SELECT Budget, SUM(Budget) AS Budget  FROM DisabilitySupportPrograms  WHERE Year = 2025  GROUP BY Year  ORDER BY Budget ASC  ) AS Budget;
# SQL of truth: SELECT ProgramName, Budget FROM DisabilitySupportPrograms WHERE Year = 2025 ORDER BY Budget DESC;
# --------
#
# Prompt:What is the average number of smart contracts developed per developer in Africa?
# --------
# SQL of res: SELECT AVG(sc.id) / COUNT(d) AS average_contracts FROM developers d LEFT JOIN smart_contracts sc ON scveloper_id = d.id WHERE d.country = 'Africa' AND sc.id IS NOT NULL;
# SQL of truth: SELECT AVG(sc_per_dev) FROM (SELECT COUNT(*) as sc_per_dev FROM smart_contracts sc INNER JOIN developers d ON sc.developer_id = d.id GROUP BY d.id) as subquery;
# --------
#
# Prompt:Find the average amount donated by donors from the USA.
# --------
# SQL of res: SELECT AVG(d.Amount) AS AverageDonationAmount FROM Donations d LEFT JOIN Donors ON d.DonorID = Donors.DirectorID WHERE Donors.Country = 'USA' AND d.DonorID IS NOT NULL;
# SQL of truth: SELECT AVG(Amount) as AverageDonation FROM Donors JOIN Donations ON Donors.DonorID = Donations.DonorID WHERE Donors.Country = 'USA';
# --------
#
# Prompt:What is the percentage of players who prefer FPS and action genres out of the total number of players?
# --------
# SQL of res: SELECT (SELECT (Genre = 'FPS' * COUNT(*) + (Genre = 'Action' * COUNT(*) / COUNT(*) AS Percentage) FROM TotalPlayers) AS Percentage;
# SQL of truth: SELECT COUNT(*) * 100.0 / (SELECT COUNT(*) FROM TotalPlayers) FROM TotalPlayers WHERE Genre IN ('FPS', 'Action');
# --------
#
# Prompt:What is the average speed of high-speed trains in Beijing, China?
# --------
# SQL of res: SELECT AVG(end_time) / trip_duration) AS average_speed  FROM high_speed_trains   WHERE city = 'Beijing' AND country = 'China';
# SQL of truth: SELECT AVG(trip_duration / (end_time - start_time)) FROM high_speed_trains WHERE city = 'Beijing' AND line LIKE '%high-speed%';
# --------
#
# Prompt:What is the percentage of trips that are multimodal?
# --------
# SQL of res: SELECT COUNT(*) WHERE mode1 IS NOT NULL AND mode2 IS NOT NULL FROM trips
# SQL of truth: SELECT AVG(CASE WHEN mode1 <> mode2 THEN 1 ELSE 0 END) as avg_multimodal FROM trips;
# --------
#
# Prompt:Display policy_id and sum_insured for policies where the sum insured is less than 60000 and policyholder gender is female
# --------
# SQL of res: SELECT policy_id, sum_insured  FROM policy_info  INNER JOIN policyholder ON policy_id = policyholder.policy_id  WHERE sum_insured < 60000 AND policyholder.gender = 'Female';
# SQL of truth: SELECT policy_info.policy_id, policy_info.sum_insured FROM policy_info INNER JOIN policyholder ON policy_info.policy_id = policyholder.policy_id WHERE policy_info.sum_insured < 60000 AND policyholder.gender = 'Female';
# --------
#
# Prompt:What is the gender breakdown of attendees for the 'African Art' event?
# --------
# SQL of res: SELECT Gender AS Gender, COUNT(*) AS Attendance FROM GROUP BY Gender FROM Audience WHERE Occupation = 'African Art Specialist' AND EventID = 1;
# SQL of truth: SELECT Audience.Gender, COUNT(*) AS Attendance FROM Audience INNER JOIN Events ON Audience.EventID = Events.EventID WHERE Events.EventName = 'African Art' GROUP BY Audience.Gender;
# --------
#
# Prompt:How many healthcare facilities are there in total, by type, in the database?
# --------
# SQL of res: SELECT type, count FROM ( SELECT COUNT(*) AS count FROM hospitals WHERE type = type UNION ( SELECT COUNT(*) FROM clinics GROUP BY type UNION ( SELECT COUNT(*) FROM long_term_care GROUP BY type AS type ) ) GROUP BY type );
# SQL of truth: SELECT type, COUNT(*) FROM hospitals GROUP BY type UNION SELECT type, COUNT(*) FROM clinics GROUP BY type UNION SELECT type, COUNT(*) FROM long_term_care GROUP BY type;
# --------
#
# Prompt:What is the number of cancer screenings performed, by gender?
# --------
# SQL of res: SELECT gender, COUNT(num_screenings) AS total_screenings FROM cancer_screenings  GROUP BY gender  ORDER BY COUNT(num_screenings DESC);
# SQL of truth: SELECT gender, SUM(num_screenings) as total_screenings FROM cancer_screenings GROUP BY gender;
# --------
#
# Prompt:Which countries produce cruelty-free skincare products and how many are there?
# --------
# SQL of res: SELECT country_name AS country, cruelty_free_count AS product_count AS product_count     FROM cruelty_free_products     WHERE cruelty_free = TRUE;
# SQL of truth: SELECT country, SUM(product_count) as total_products FROM cruelty_free_products WHERE cruelty_free = true GROUP BY country;
# --------
#
# Prompt:How many emergency response vehicles are stationed in each borough?
# --------
# SQL of res: SELECT b.id AS id, b.name AS borough_name, SUM(sts.num_vehicles) AS total_vehicles  FROM borough b   LEFT JOIN stations sts ON b.id = id = borough_id   GROUP BY b.id, b.name;
# SQL of truth: SELECT b.name, s.num_vehicles FROM stations s JOIN borough b ON s.borough_id = b.id;
# --------
#
# Prompt:List the intelligence operations and their corresponding threat levels, and rank them based on their threat level and budget.
# --------
# SQL of res: SELECT operation, threat, budget FROM (threat AS threat_level, operation, budget AS budget_value FROM intel_ops_threat) ORDER BY threat_level DESC, budget DESC;
# SQL of truth: SELECT operation, threat, budget, ROW_NUMBER() OVER (PARTITION BY threat ORDER BY budget DESC) as rank FROM intel_ops_threat;
# --------
#
# Prompt:What is the diversity ratio (percentage of non-male employees) in each department?
# --------
# SQL of res: SELECT Department, (COUNT(* WHERE Gender != 'Male') / COUNT(*)) * 100 AS Non_Male_Percent FROM Employees GROUP BY Department;
# SQL of truth: SELECT Department, (COUNT(CASE WHEN Gender <> 'Male' THEN 1 END) / COUNT(*)) * 100 AS DiversityRatio FROM Employees GROUP BY Department;
# --------
#
# Prompt:What is the percentage of meals that meet the daily recommended nutrient intake for customers in Indonesia?
# --------
# SQL of res: SELECT COUNT(*) / COUNT(*) FROM (SELECT * COUNT(*) AS percentage_of_meals_with_intake FROM meals m JOIN customers c ON m.customer_id = c.id WHERE m.customer_id = c.id AND c.country = 'Indonesia');
# SQL of truth: SELECT (COUNT(*) FILTER (WHERE meals.calories >= (meals.daily_recommended_intake * 0.8))) * 100.0 / COUNT(*) AS percentage FROM meals JOIN customers ON meals.customer_id = customers.id WHERE customers.country = 'Indonesia';
# --------
#
# Prompt:What is the engagement rate of virtual tours in European hotels?
# --------
# SQL of res: SELECT AVG(vt.views) / COUNT(h.id) AS engagement_rate FROM hotels AS h INNER JOIN virtual_tours vt ON h.hotel_id = vt.hotel_id  WHERE h.country IN ('France', 'Germany', 'Italy');
# SQL of truth: SELECT country, AVG(views / (SELECT SUM(views) FROM virtual_tours WHERE hotel_id = hotels.hotel_id) * 100) as engagement_rate FROM hotels INNER JOIN virtual_tours ON hotels.hotel_id = virtual_tours.hotel_id GROUP BY country;
# --------
#
# Prompt:What is the average price of paintings from African artists in our collection?
# --------
# SQL of res: SELECT AVG(price) AS average_price FROM Artworks WHERE medium = 'Painting' AND medium = 'African' AND continent = 'Africa';
# SQL of truth: SELECT AVG(Artworks.price) FROM Artworks INNER JOIN Collections ON Artworks.artist_nationality = Collections.continent WHERE Artworks.medium = 'Painting' AND Collections.continent = 'Africa';
# --------
#
# Prompt:What is the total number of marine life research stations and pollution control initiatives in the Southern Ocean?
# --------
# SQL of res: SELECT COUNT(*) FROM marine_life_research_stations WHERE region = 'Southern Ocean'; SELECT COUNT(*) FROM pollution_control_initiatives WHERE region = 'Southern Ocean';
# SQL of truth: SELECT SUM(cnt) FROM (SELECT COUNT(*) cnt FROM marine_life_research_stations WHERE region = 'Southern Ocean' UNION ALL SELECT COUNT(*) FROM pollution_control_initiatives WHERE region = 'Southern Ocean') x;
# --------
#
# Prompt:What is the total quantity of locally sourced ingredients used in dishes?
# --------
# SQL of res: SELECT SUM(di.quantity) AS total FROM ingredients i     INNER JOIN dishes d ON i.ingredient = d.ingredient WHERE i.ingredient = 'Carrots' AND i.is_local = TRUE;
# SQL of truth: SELECT SUM(quantity) AS total_local_ingredients FROM dish_ingredients DI INNER JOIN ingredients I ON DI.ingredient = I.ingredient WHERE I.is_local = TRUE;
# --------
#
# Prompt:What is the difference in ocean acidity levels between the Atlantic and Pacific Oceans?
# --------
# SQL of res: SELECT ph1 - ph2 AS ph_diff     FROM ocean_ph     WHERE location = 'Atlantic Ocean'     WHERE location = 'Pacific Ocean';
# SQL of truth: SELECT MAX(ph) - MIN(ph) FROM ocean_ph WHERE location IN ('Atlantic Ocean', 'Pacific Ocean');
# --------
#
# Prompt:What is the total budget allocated for education and healthcare services in 2020, for regions with a population over 1 million?
# --------
# SQL of res: SELECT SUM(b.amount) AS total_budget FROM budget b LEFT JOIN regions r ON (b.service = ('Education','Healthcare') AND b.year = 2020) AND r.population > 1000000;
# SQL of truth: SELECT SUM(b.amount) FROM budget b INNER JOIN regions r ON b.region_id = r.id WHERE b.service IN ('Education', 'Healthcare') AND b.year = 2020 AND r.population > 1000000;
# --------
#
# Prompt:What is the total quantity of 'Tencel Lyocell' and 'Bamboo Viscose' fabrics in stock?
# --------
# SQL of res: SELECT SUM(quantity) AS total_quantity FROM (SELECT fabric_name) AND quantity NOT IN (SELECT quantity) FROM inventory WHERE fabric_name = 'Tencel Lyocell' OR fabric_name = 'Bamboo Viscose';
# SQL of truth: SELECT SUM(quantity) as total_quantity FROM inventory WHERE fabric_name IN ('Tencel Lyocell', 'Bamboo Viscose');
# --------
#
# Prompt:What is the total number of electric vehicles sold in 'California' in the 'sales' schema?
# --------
# SQL of res: SELECT SUM(sales.vehicle_count)  AS total_sold_electrics FROM sales JOIN vehicles ON vehicles.id = 1 JOIN regions ON sales.region_id =  regions.id AND regions.name = 'California' WHERE vehicles.type = 'electric';
# SQL of truth: SELECT SUM(sales.vehicle_count) FROM sales INNER JOIN sales_regions ON sales.region_id = sales_regions.id INNER JOIN vehicles ON sales.id = vehicles.id WHERE vehicles.type = 'electric' AND sales_regions.name = 'California';
# --------
#
# Prompt:What is the minimum salary for each job title in the IT department?
# --------
# SQL of res: SELECT JobTitle, MIN(EmployeeSalary AS MinSalary), Department FROM JobSalaries GROUP BY JobTitle WHERE Department = 'IT';
# SQL of truth: SELECT JobTitle, MIN(EmployeeSalary) FROM JobSalaries WHERE Department = 'IT' GROUP BY JobTitle;
# --------
#
# Prompt:Which warehouse has the lowest quantity of item 'ORG-01'?
# --------
# SQL of res: SELECT w.name FROM warehouse AS w INNER JOIN inventory i ON w.id AS warehouse_id = i.id     WHERE i.item_code = 'ORG-01' GROUP BY w.name ORDER BY i.quantity ASC LIMIT 1;
# SQL of truth: SELECT warehouse_id, MIN(quantity) FROM inventory WHERE item_code = 'ORG-01' GROUP BY warehouse_id;
# --------
#
# Prompt:What is the total revenue for concerts in Canada for artists who identify as non-binary and are from Asia in 2023?
# --------
# SQL of res: SELECT SUM(revenue) AS total_revenue FROM concert_events WHERE event_date = '2023%' AND gender = 'non-binary'    AND ethnicity = 'Asian'   AND country = 'Canada';
# SQL of truth: SELECT SUM(revenue) FROM concert_events ce JOIN artist_demographics ad ON ce.artist_id = ad.artist_id WHERE ce.country = 'Canada' AND ad.gender = 'non-binary' AND ad.ethnicity = 'Asian' AND ce.event_date BETWEEN '2023-01-01' AND '2023-12-31';
# --------
#
# Prompt:Find the top 5 donors by summed donation amounts for each country?
# --------
# SQL of res: SELECT d.Count, SUM(d.Amount) AS TotalDonation FROM Donors d INNER JOIN Donations d ON d.DonorID = d.DonorID ORDER BY TotalDonation DESC LIMIT 5;
# SQL of truth: SELECT d.Country, d.DonorID, SUM(donations.Amount) AS TotalDonated FROM Donors d JOIN Donations ON d.DonorID = Donations.DonorID GROUP BY d.Country, d.DonorID ORDER BY TotalDonated DESC LIMIT 5;
# --------
#
# Prompt:Show the number of workers in factories that have passed the ethical labor audit.
# --------
# SQL of res: SELECT COUNT(w.worker_id) AS worker_count FROM factories f JOIN workers w ON f.factory_id = w.factory_id WHERE f.audit_passed = TRUE;
# SQL of truth: SELECT COUNT(DISTINCT workers.worker_id) FROM workers INNER JOIN factories ON workers.factory_id = factories.id WHERE factories.audit_passed = TRUE;
# --------
#
# Prompt:What is the total number of vulnerabilities found in the 'Finance' department?
# --------
# SQL of res: SELECT COUNT(*) AS total_vulnerabilities_count FROM (SELECT * FROM vulnerabilities v INNER JOIN department ON v.department_id = (SELECT d.id FROM department) AS d WHERE d.name = 'Finance') AS sub WHERE department_id = 1;
# SQL of truth: SELECT COUNT(*) FROM vulnerabilities WHERE department_id = (SELECT id FROM department WHERE name = 'Finance');
# --------
#
# Prompt:What is the average community development initiative budget per country, ordered by the largest budget?
# --------
# SQL of res: SELECT CountryName AS CountryName, AVG(CD.Budget) AS AverageBudget FROM Country C LEFT JOIN CommunityDevelopment CD ON C.CountryID = CD.CountryID GROUP BY CountryName) AS CountryStats ORDER BY AverageBudget DESC
# SQL of truth: SELECT CountryName, AVG(Budget) AS AvgBudget FROM Country JOIN CommunityDevelopment ON Country.CountryID = CommunityDevelopment.CountryID GROUP BY CountryName ORDER BY AvgBudget DESC;
# --------
#
# Prompt:What is the percentage of community development projects completed in 'Caribbean' in 2020?
# --------
# SQL of res: SELECT (completions / (SELECT COUNT(*) AS total FROM community_projects)) * 100 AS percentage FROM (SELECT COUNT(*)  FROM community_projects WHERE location = 'Caribbean' AND completion_year = 2020);
# SQL of truth: SELECT (COUNT(*) * 100.0 / (SELECT COUNT(*) FROM community_projects WHERE location = 'Caribbean')) FROM community_projects WHERE completion_year = 2020 AND location = 'Caribbean';
# --------
#
# Prompt:What is the total number of animals in protected habitats for each region?
# --------
# SQL of res: SELECT (     SELECT region, COUNT(animal_id) AS total_animals     FROM ProtectedHabitats     GROUP BY region ) AS region_totals;
# SQL of truth: SELECT region, COUNT(animal_id) FROM ProtectedHabitats GROUP BY region;
# --------
#
# Prompt:What is the median hourly wage for construction laborers in Louisiana?
# --------
# SQL of res: SELECT PERCENTILE_CONT(0.50) AS median_wage     FROM la_wages     WHERE job = 'Construction laborer';
# SQL of truth: SELECT AVG(hourly_wage) FROM la_wages WHERE job = 'Construction laborer';
# --------
#
# Prompt:Calculate the moving average of chemical waste production for each facility, for the last 6 months.
# --------
# SQL of res: SELECT facility_id,        AVG(waste_amount) / COUNT(*) / 6 AS moving_average   FROM facility_waste   WHERE date >= CURRENT_DATE - INTERVAL '6 months'   GROUP BY facility_id;
# SQL of truth: SELECT facility_id, AVG(waste_amount) OVER (PARTITION BY facility_id ORDER BY date ROWS BETWEEN 5 PRECEDING AND CURRENT ROW) as moving_average FROM facility_waste;
# --------
#
# Prompt:How much have countries invested in climate communication in Asia?
# --------
# SQL of res: SELECT SUM(investment_1) AS total_invest FROM (SELECT Investment_Amount FROM CommInvestment WHERE Country IN ('China', 'Japan', 'India')) AS investments;
# SQL of truth: SELECT SUM(Investment_Amount) FROM CommInvestment WHERE Country IN ('China', 'Japan', 'India') AND Investment_Amount IS NOT NULL;
# --------
#
# Prompt:What is the average investment in sustainable agriculture per country?
# --------
# SQL of res: SELECT country, AVG(amount) AS average_investment FROM ( SELECT investments GROUP BY country ) WHERE sector = 'Sustainable Agriculture' ) GROUP BY country;
# SQL of truth: SELECT country, AVG(amount) as avg_investment FROM investments WHERE sector = 'Sustainable Agriculture' GROUP BY country;
# --------
#
# Prompt:How many renewable energy projects were completed in Colombia and Peru in 2020 and 2021?
# --------
# SQL of res: SELECT SUM(num_projects) AS total_projectsCompleted FROM latam_renewable_projects WHERE country IN (SELECT FROM country) AND year IN (SELECT FROM year)
# SQL of truth: SELECT SUM(num_projects) FROM latam_renewable_projects WHERE country IN ('Colombia', 'Peru') AND year BETWEEN 2020 AND 2021;
# --------
#
# Prompt:List the fashion trends of 2021 with sales greater than 1500?
# --------
# SQL of res: SELECT column1 AS id, product, sales FROM trends_2021 WHERE sales > 1500;
# SQL of truth: SELECT product FROM trends_2021 WHERE sales > 1500;
# --------
#
# Prompt:Show annual energy consumption for our sustainable seafood processing plants, in kWh.
# --------
# SQL of res: SELECT * (     SELECT annual_energy_consumption     FROM plants     WHERE name = 'Seafood Haven' AND type = 'Sustainable' ) AS energy
# SQL of truth: SELECT name, annual_energy_consumption FROM plants WHERE type = 'Sustainable';
# --------
#
# Prompt:List the traditional arts that have been represented in the most heritage sites, ordered by the number of heritage sites in descending order.
# --------
# SQL of res: SELECT ArtName, ArtType, COUNT(sa.site_id) AS SiteCount FROM Arts  LEFT JOIN SiteArts sa ON Arts.ArtID = sa.art_id  GROUP BY ArtName, ArtType  ORDER BY SiteCount DESC;
# SQL of truth: SELECT ArtType, COUNT(SiteID) AS Number_Of_Sites FROM SiteArts JOIN Arts ON SiteArts.ArtID = Arts.ArtID GROUP BY ArtType ORDER BY Number_Of_Sites DESC;
# --------
#
# Prompt:What is the number of players who have played more than 100 minutes?
# --------
# SQL of res: SELECT COUNT(id) AS count FROM players WHERE player_name IN (   SELECT player_name   FROM player_sessions WHERE playtime > 100 );
# SQL of truth: SELECT COUNT(*) FROM player_sessions WHERE playtime > 100;
# --------
#
# Prompt:List all unique types of cargo loaded onto vessels in the Atlantic region.
# --------
# SQL of res: SELECT DISTINCT cargo.cargo_type FROM cargo JOIN vessels v     ON (cargo.vessel_id = v.id) AND (region = 'Atlantic' OR (id = 2) ) AND (v.region = 'Atlantic' );
# SQL of truth: SELECT DISTINCT cargo_type FROM cargo c JOIN vessels v ON c.vessel_id = v.id WHERE v.region = 'Atlantic';
# --------
#
# Prompt:What is the average cargo quantity per vessel for each vessel type?
# --------
# SQL of res: SELECT v.Type AS Type, AVG(c.Quantity) AS Average_Quantity     FROM Vessels v     INNER JOIN Cargo c ON c.VesselId = Vessels.Id     GROUP BY v.Type;
# SQL of truth: SELECT Vessels.Type, AVG(Cargo.Quantity) as AverageCargoQuantity FROM Cargo JOIN Vessels ON Cargo.VesselId = Vessels.Id GROUP BY Vessels.Type;
# --------
#
# Prompt:How many recycling plants in Canada process exactly 5 types of waste?
# --------
# SQL of res: SELECT COUNT(*) AS (  SELECT COUNT(*) AS recycling_plants  FROM recycling_plants  WHERE country = 'Canada'  AND waste_types = 5 )
# SQL of truth: SELECT COUNT(*) FROM recycling_plants WHERE country = 'Canada' AND waste_types = 5;
# --------
#
# Prompt:How many creative AI applications were developed in the 'americas' region in 2022?
# --------
# SQL of res: SELECT SUM(application_count) AS applications  FROM creative_ai   WHERE region = 'americas'   AND year = 2022;
# SQL of truth: SELECT SUM(applications) FROM creative_ai WHERE region = 'americas' AND year = 2022;
# --------
#
# Prompt:Which strain was the best seller in Colorado in 2021?
# --------
# SQL of res: SELECT strain_name, quantity AS quantity FROM sales WHERE state = 'Colorado' AND year = '2021' ORDER BY quantity DESC DESC LIMIT 1
# SQL of truth: SELECT strain, SUM(quantity) as total_quantity FROM sales WHERE state = 'Colorado' AND year = 2021 GROUP BY strain ORDER BY total_quantity DESC LIMIT 1;
# --------
#
# Prompt:What is the success rate of cases handled by attorneys who have passed the bar exam in the state where they practice?
# --------
# SQL of res: (SELECT COUNT(*) FROM Cases WHERE Outcome = 'won') AS (1 / COUNT(*)) AS SuccessRate FROM Cases  INNER JOIN Attorneys ON AttorneyID = (SELECT State FROM Attorneys WHERE BarPassed = 'yes' AND State = State);
# SQL of truth: SELECT AVG(CASE WHEN Outcome = 'won' THEN 1.0 ELSE 0.0 END) as SuccessRate FROM Cases C INNER JOIN Attorneys A ON C.AttorneyID = A.AttorneyID WHERE A.BarPassed = 'yes';
# --------
#
# Prompt:What is the average annual rainfall in Asia for the last 5 years?
# --------
# SQL of res: SELECT AVG(rainfall) AS average_rainfall     FROM AS     WHERE year BETWEEN 2015 AND 2019;
# SQL of truth: SELECT AVG(rainfall) FROM rainfall_asia WHERE country = 'AS' AND year BETWEEN 2015 AND 2019;
# --------
#
# Prompt:Who are the top 3 goal scorers in the FIFA World Cup?
# --------
# SQL of res: SELECT player_name, SUM(column) AS goals_total FROM world_cup_goals GROUP BY player_name ORDER BY goals_total DESC LIMIT 3;
# SQL of truth: SELECT player_name, goals FROM world_cup_goals ORDER BY goals DESC LIMIT 3;
# --------
#
# Prompt:Who has the highest number of wins as a coach for each team in a season?
# --------
# SQL of res: SELECT CoachID, CoachName FROM Coach JOIN SELECT CoachID, CoachName FROM Coach SELECT FROM Coach WHERE CoachID = CoachID FROM Coach WHERE CoachID = CoachID WHERE CoachID = CoachID ORDER BY CoachID DESC LIMIT 1 AS TopCoach
# SQL of truth: SELECT c.TeamID, c.CoachName, COUNT(CASE WHEN h.HomeTeamResult = 'Win' THEN 1 END) + COUNT(CASE WHEN a.HomeTeamResult = 'Win' THEN 1 END) AS Wins FROM Coach c LEFT JOIN Match h ON c.TeamID = h.HomeTeamID AND h.HomeTeamResult = 'Win' LEFT JOIN Match a ON c.TeamID = a.AwayTeamID AND a.HomeTeamResult = 'Win' GROUP BY c.TeamID, c.CoachName ORDER BY Wins DESC;
# --------
#
# Prompt:What is the average fare collected per trip for buses in the city of Seattle?
# --------
# SQL of res: SELECT AVG(f.fare) AS average_fare_per_trip   FROM buses b   JOIN fares f ON (b.id = 1 AND f.city = 'Seattle')   WHERE b.city = 'Seattle';
# SQL of truth: SELECT AVG(f.fare) FROM fares f JOIN buses b ON f.bus_id = b.id WHERE b.city = 'Seattle';
# --------
#
# Prompt:What is the average financial wellbeing score in Q2 2022 for customers with a Shariah-compliant finance account?
# --------
# SQL of res: SELECT AVG(financial_wellbeing_score) AS average_score FROM  shariah_compliant_customers WHERE shariah_compliant_account = TRUE AND wellbeing_assessment_date BETWEEN '2022-04-01'...
# SQL of truth: SELECT AVG(financial_wellbeing_score) FROM shariah_compliant_customers WHERE shariah_compliant_account = true AND wellbeing_assessment_date BETWEEN '2022-04-01' AND '2022-06-30';
# --------
#
# Prompt:What is the total quantity of dairy products sold in each country?
# --------
# SQL of res: SELECT c.CountryName, SUM(pd.QuantitySold) AS TotalQuantitySold FROM Countries AS c JOIN Products AS pd ON c.CountryID = pd.CountryID WHERE pd.Dairy = true GROUP BY c.CountryName;
# SQL of truth: SELECT c.CountryName, p.ProductName, SUM(p.QuantitySold) as TotalQuantitySold FROM Countries c JOIN Products p ON c.CountryID = 1 GROUP BY c.CountryName, p.ProductName HAVING p.Dairy = true;
# --------
#
# Prompt:What is the maximum property price in wheelchair-accessible neighborhoods in Singapore?
# --------
# SQL of res: SELECT MAX(sn.Property_Price) AS Maximum_Price FROM Singapore_Properties JOIN Singapore_Neighborhoods sn ON sn.Neighborhood_Name = 'Singapore' WHERE sn.Wheelchair_Accessibility = TRUE;
# SQL of truth: SELECT MAX(Singapore_Properties.Property_Price) FROM Singapore_Properties INNER JOIN Singapore_Neighborhoods ON Singapore_Properties.Neighborhood_Name = Singapore_Neighborhoods.Neighborhood_Name WHERE Singapore_Neighborhoods.Wheelchair_Accessibility = true;
# --------
#
# Prompt:Which suppliers have provided raw materials for the production of chemicals with high environmental impact?
# --------
# SQL of res: SELECT DISTINCT s.id, s.name FROM suppliers s JOIN raw_materials rm ON s.supplier_id = rm.id JOIN chemicals c ON rm.chemical_id = c.id WHERE c.environment_impact > 15;
# SQL of truth: SELECT s.name FROM suppliers s INNER JOIN raw_materials rm ON s.id = rm.supplier_id INNER JOIN chemicals c ON rm.chemical_id = c.id WHERE c.environmental_impact > 10;
# --------
#
# Prompt:What is the total funding allocated for climate adaptation in 'Europe'?
# --------
# SQL of res: SELECT SUM(cf.allocation) AS total_funding FROM climate_funding cf   JOIN regions r ON cf.region_id = r.id   WHERE initiative_type = 'Adaptation' AND   AND r.region = 'Europe';
# SQL of truth: SELECT SUM(allocation) FROM climate_funding INNER JOIN regions ON climate_funding.region_id = regions.id WHERE regions.region = 'Europe' AND climate_funding.initiative_type = 'Adaptation';
# --------
#
# Prompt:What are the top 3 countries with the highest R&D expenditures in 2020?
# --------
# SQL of res: SELECT country, amount FROM rd_expenditures WHERE year = 2020 ORDER BY amount DESC LIMIT country, amount 3;
# SQL of truth: SELECT country, SUM(amount) as total_expenditure FROM rd_expenditures WHERE year = 2020 GROUP BY country ORDER BY total_expenditure DESC LIMIT 3;
# --------
#
# Prompt:What is the most common type of cancer in Australia?
# --------
# SQL of res: SELECT country_name, type FROM (SELECT country, type FROM cancer_data WHERE country = country_name GROUP BY country, type ORDER BY cases DESC LIMIT 1) AS result;
# SQL of truth: SELECT type, cases FROM cancer_data WHERE country = 'Australia' ORDER BY cases DESC LIMIT 1;
# --------
#
# Prompt:What marine species have been observed in both the Arctic and Southern Oceans?
# --------
# SQL of res: SELECT name FROM species s JOIN oceans o ON s.ocean_id = o.ocean_id WHERE (ocean_id = 1 AND s.ocean_id = 2);
# SQL of truth: SELECT s.name FROM species s WHERE s.ocean_id IN (1, 2) GROUP BY s.name HAVING COUNT(DISTINCT s.ocean_id) = 2;
# --------
#
# Prompt:List all ingredients used in products from a specific brand.
# --------
# SQL of res: SELECT DISTINCT ingredient FROM ingredients AS ingredient_product JOIN ingredients AS ingredient_product ON ingredient_product.product_id = ingredient_product.product_id  JOIN ingredients AS ingredient ON ingredient_product.product_id = ingredient.product_id FROM brands  WHERE brand_name = 'Estée Lauder';
# SQL of truth: SELECT ingredient FROM ingredients INNER JOIN brands ON ingredients.brand_id = brands.brand_id WHERE brand_name = 'Lush';
# --------
#
# Prompt:What is the average salary of 'engineer' workers in each factory?
# --------
# SQL of res: SELECT factory.factory_name, AVG(salary) AS average_salary FROM workers LEFT JOIN factory ON workers.factory_id = factory.factory_id WHERE role_name = 'engineer' GROUP BY factory.factory_name;
# SQL of truth: SELECT f.factory_name, AVG(salary) FROM workers w INNER JOIN factories f ON w.factory_id = f.factory_id INNER JOIN roles r ON w.role_id = r.role_id WHERE r.role_name = 'engineer' GROUP BY f.factory_name;
# --------
#
# Prompt:Which football teams have the highest number of wins in the 2021-2022 season?
# --------
# SQL of res: SELECT team_name, wins AS wins FROM football_teams WHERE wins >= MAX(wins) AND wins >= MAX(wins) ORDER BY wins DESC LIMIT 1;
# SQL of truth: SELECT team_name, wins FROM football_teams ORDER BY wins DESC LIMIT 2;
# --------
#
# Prompt:What is the total quantity of items shipped per warehouse to each country?
# --------
# SQL of res: SELECT     WarehouseId,     Destination AS DestinationCountry,     SUM(Quantity) AS TotalQuantity FROM     Shipments GROUP BY     WarehouseId, Destination AS DestinationCountry ORDER BY     WarehouseId, DestinationCountry;
# SQL of truth: SELECT WarehouseId, Destination, SUM(Quantity) AS TotalQuantity FROM Shipments GROUP BY WarehouseId, Destination;
# --------
#
# Prompt:What was the change in water consumption between 2020 and 2021 for each city?
# --------
# SQL of res: SELECT city, consumption(2021) - consumption(2020) AS consumption_change FROM city_water_usage WHERE city = city;
# SQL of truth: SELECT a.city, (a.consumption - b.consumption) AS consumption_change FROM city_water_usage a INNER JOIN city_water_usage b ON a.city = b.city AND a.year = 2021 AND b.year = 2020;
# --------
#
# Prompt:What was the minimum price per gram of the Gelato strain in Nevada in 2022?
# --------
# SQL of res: SELECT MIN(price / grams) AS min_price_per_gram  FROM inventory WHERE state = ? AND year = ? AND strain = ? -- AND grams = ? --;
# SQL of truth: SELECT MIN(price/grams) FROM inventory WHERE state = 'Nevada' AND year = 2022 AND strain = 'Gelato';
# --------
#
# Prompt:Identify attorneys who have never handled cases in the 'West' region but have in the 'North' or 'South'.
# --------
# SQL of res: SELECT attorney_id, region FROM attorney_regions WHERE region = 'West' AND NOT EXISTS (     SELECT * FROM handled_cases WHERE attorney_id = (SELECT * FROM attorney_regions AND region IN ('North', 'South')) );
# SQL of truth: SELECT h.attorney_id FROM attorney_regions h LEFT JOIN handled_cases i ON h.attorney_id = i.attorney_id WHERE h.region IN ('North', 'South') AND h.region != 'West' AND i.attorney_id IS NOT NULL AND h.attorney_id NOT IN (SELECT attorney_id FROM attorney_regions WHERE region = 'West');
# --------
#
# Prompt:Find the number of healthcare providers in each type of facility in the rural healthcare system.
# --------
# SQL of res: SELECT FacilityType, TypeOfProvider, COUNT(*) AS ProviderCount FROM Providers WHERE FacilityType = 'Rural' GROUP BY FacilityType, TypeOfProvider;
# SQL of truth: SELECT FacilityType, COUNT(*) AS Total FROM Providers GROUP BY FacilityType;
# --------
#
# Prompt:How many volunteers joined after participating in a community outreach event in '2020'?
# --------
# SQL of res: SELECT SUM(num_volunteers)  FROM volunteer_events WHERE id NOT IN (SELECT * FROM community_outreach WHERE year = 2020);
# SQL of truth: SELECT SUM(num_volunteers) FROM volunteer_events WHERE year = 2020 AND event_name IN (SELECT event_name FROM volunteer_events WHERE year = 2020 AND num_volunteers > 0);
# --------
#
# Prompt:List the top 5 players with the highest points per game, including their team name and average points per game.
# --------
# SQL of res: SELECT name, AVG(points_per_game DESC) AS avg_points_per_game, team FROM players ORDER BY AVG(points_per_game DESC), team ASC LIMIT 5;
# SQL of truth: SELECT p.name, p.team, AVG(p.points_per_game) as avg_points_per_game FROM players p GROUP BY p.name, p.team ORDER BY avg_points_per_game DESC LIMIT 5;
# --------
#
# Prompt:How many volunteers with 'Medical' skills were assigned before a volunteer with 'Engineering' skills?
# --------
# SQL of res: SELECT COUNT(*) AS medical_count FROM volunteers_ext WHERE skill = 'Medical' AND skill = 'Engineering' AND assignment_date < (SELECT assignment_date FROM ())
# SQL of truth: SELECT COUNT(*) FROM (SELECT skill, assignment_date, LAG(skill) OVER (ORDER BY assignment_date) AS prev_skill FROM volunteers_ext WHERE skill = 'Medical') t WHERE prev_skill = 'Engineering';
# --------
#
# Prompt:Which station on the 'Red' line has the lowest fare collection?
# --------
# SQL of res: SELECT station, revenue FROM (SELECT station FROM routes WHERE line = 'Red' AND station = (SELECT station FROM fares WHERE revenue = (SELECT MIN(revenue) FROM fares WHERE line NOT = NULL AS line) AND line NOT = NULL AS line));
# SQL of truth: SELECT station, MIN(revenue) FROM fares WHERE station IN (SELECT station FROM routes WHERE line = 'Red') GROUP BY station;
# --------
#
# Prompt:How many shipments were made from each country?
# --------
# SQL of res: SELECT (     SELECT country, COUNT(*) AS shipment_count   ) AS country_count   FROM shipments   GROUP BY country   ORDER BY country_count DESC;
# SQL of truth: SELECT country, COUNT(*) as total_shipments FROM shipments GROUP BY country;
# --------
#
# Prompt:What is the minimum, maximum, and average age of victims who have participated in restorative justice programs, by location?
# --------
# SQL of res: SELECT location, MIN(age) AS min_age, MAX(age) AS max_age, AVG(age) AS avg_age FROM (victim LEFT JOIN participant ON (id = victim_id WHERE victim_id IS NOT NULL)) GROUP BY location;
# SQL of truth: SELECT location, MIN(v.age) AS min_age, MAX(v.age) AS max_age, AVG(v.age) AS avg_age FROM victims v JOIN restorative_justice_participants rjp ON v.id = rjp.victim_id GROUP BY location;
# --------
#
# Prompt:Show the total number of marine protected areas in the Pacific Ocean
# --------
# SQL of res: {     SELECT COUNT(*) AS total_marine_protected_areas     FROM marine_protected_areas     WHERE location = 'Pacific Ocean'; }
# SQL of truth: SELECT COUNT(*) FROM marine_protected_areas WHERE location = 'Pacific Ocean';
# --------
#
# Prompt:What is the average age of players who play VR games and their total spending on games?
# --------
# SQL of res: SELECT      AVG(p.age) AS average_age,     SUM(pg.price) AS total_spending FROM players p     JOIN player_games pg ON p.id = pg.player_id     WHERE pg.type = 'VR';
# SQL of truth: SELECT AVG(players.age), SUM(games.price) FROM players INNER JOIN player_games ON players.id = player_games.player_id INNER JOIN games ON player_games.game_id = games.id WHERE games.type = 'VR';
# --------
#
# Prompt:What is the average energy efficiency score for buildings in each country, ordered by the highest average score?
# --------
# SQL of res: SELECT country, AVG(efficiency_score) AS avg_efficiency_score FROM Buildings GROUP BY country ORDER BY AVG(efficiency_score DESC);
# SQL of truth: SELECT country, AVG(efficiency_score) AS avg_efficiency_score  FROM Buildings GROUP BY country ORDER BY avg_efficiency_score DESC;
# --------
#
# Prompt:Show the names of suppliers that provide materials for at least 3 products.
# --------
# SQL of res: SELECT DISTINCT m.supplier_name FROM materials m JOIN products p ON m.supplier_id = p.product_id  GROUP BY material_id, supplier_id, material_name HAVING COUNT(material_id) >= 3;
# SQL of truth: SELECT supplier_id FROM materials GROUP BY supplier_id HAVING COUNT(DISTINCT product_id) >= 3;
# --------
#
# Prompt:Get the count of 'Vegan Leather Shoes' orders in France with a quantity greater than 3.
# --------
# SQL of res: SELECT COUNT(*) AS count FROM orders FROM (SELECT FROM garments WHERE name = 'Vegan Leather Shoes' AND country = 'France') AS garments AND quantity > 3;
# SQL of truth: SELECT COUNT(*) FROM orders INNER JOIN garments ON orders.garment_id = garments.id WHERE garments.name = 'Vegan Leather Shoes' AND garments.country = 'France' AND orders.quantity > 3;
# --------
#
# Prompt:How many workplace safety incidents were reported in the Construction industry in 2021?
# --------
# SQL of res: SELECT COUNT(incidents) AS total, ( incidents AS incidents FROM WorkplaceSafety WHERE year = 2021 AND industry = 'Construction' )
# SQL of truth: SELECT incidents FROM WorkplaceSafety WHERE industry = 'Construction' AND year = 2021;
# --------
#
# Prompt:Display economic diversification efforts and their respective program managers from the 'rural_development' database
# --------
# SQL of res: SELECT id, effort, description, program_manager FROM rural_development.economic_diversification;
# SQL of truth: SELECT effort, program_manager FROM economic_diversification;
# --------
#
# Prompt:Which species of fish has the highest average daily growth rate in the Americas?
# --------
# SQL of res: SELECT Species, AVG(DailyGrowthRate) FROM FishGrowth WHERE Region = 'Americas' AND Species = Species GROUP ORDER BY DailyGrowthRate DESC LIMIT 1;
# SQL of truth: SELECT Species, AVG(DailyGrowthRate) as AvgDailyGrowthRate FROM FishGrowth WHERE Region = 'Americas' GROUP BY Species ORDER BY AvgDailyGrowthRate DESC LIMIT 1;
# --------
#
# Prompt:What is the total number of students with and without disabilities in each academic year?
# --------
# SQL of res: SELECT year,         COUNT(*) AS total_students_count - COUNT(*) AS students_with_disability_count FROM students GROUP BY year ORDER BY year;
# SQL of truth: SELECT year, SUM(CASE WHEN disability THEN 1 ELSE 0 END) AS students_with_disabilities, SUM(CASE WHEN NOT disability THEN 1 ELSE 0 END) AS students_without_disabilities FROM students GROUP BY year;
# --------
#
# Prompt:What is the total amount of research grants awarded to the Physics department in 2021 and 2022?
# --------
# SQL of res: SELECT SUM(grant_amount) AS total_grant_amount FROM research_grants WHERE department_id = 1   AND department_name = departments.id   AND grant_year IN (2021, 2022);
# SQL of truth: SELECT SUM(grant_amount) as total_grant_amount FROM research_grants WHERE department_id = (SELECT id FROM departments WHERE department_name = 'Physics') AND grant_year IN (2021, 2022);
# --------
#
# Prompt:What is the total amount donated by donors in the 'Regular Donors' category?
# --------
# SQL of res: SELECT SUM(DonationAmount) AS Total FROM Donations   JOIN Donors  ON DonorID = DonorID   WHERE Category = 'Regular Donors';
# SQL of truth: SELECT SUM(DonationAmount) FROM Donations INNER JOIN Donors ON Donations.DonorID = Donors.DonorID WHERE Donors.Category = 'Regular Donors';
# --------
#
# Prompt:Find the total revenue for each cuisine type
# --------
# SQL of res: SELECT r.RestauranteType AS CuisineType, SUM(s.Revenue) AS TotalRevenue FROM Restaurants r JOIN Sales s ON r.RestauranteID = s.RestauranteID GROUP BY r.RestauranteType;
# SQL of truth: SELECT R.CuisineType, SUM(S.Revenue) as TotalRevenue FROM Restaurants R INNER JOIN Sales S ON R.RestaurantID = S.RestaurantID GROUP BY R.CuisineType;
# --------
#
# Prompt:How many restaurants are there in each country?
# --------
# SQL of res: SELECT COUNT(*) AS country_count FROM (SELECT country AS country, COUNT(*) AS count FROM (SELECT COUNT(*) AS country_count FROM (SELECT country FROM restaurant GROUP BY country))))
# SQL of truth: SELECT country, COUNT(*) FROM restaurant GROUP BY country;
# --------
#
# Prompt:What is the minimum price of vegan dishes in San Francisco?
# --------
# SQL of res: SELECT MIN(price) AS min_price FROM Menu WHERE restaurant_id = 1 AND category = 'Vegan' AND Restaurants.city = 'San Francisco';
# SQL of truth: SELECT MIN(price) FROM Menu JOIN Restaurants ON Menu.restaurant_id = Restaurants.id WHERE Restaurants.city = 'San Francisco' AND category = 'Vegan';
# --------
#
# Prompt:How many members in the West region have a premium membership?
# --------
# SQL of res: SELECT COUNT(DISTINCT *) AS premium_members_in_west  FROM memberships  WHERE member_type = 'premium'    AND region = 'West';
# SQL of truth: SELECT COUNT(*) FROM memberships WHERE member_type = 'Premium' AND region = 'West';
# --------
#
# Prompt:List the dapps that have deployed the fewest smart contracts in the 'Polygon' network.
# --------
# SQL of res: SELECT dapp_name FROM polygon_dapps WHERE network = 'Polygon'   AND smart_contracts = (SELECT * FROM polygon_dapps LIMIT 1);
# SQL of truth: SELECT dapp_name, network, smart_contracts, DENSE_RANK() OVER (ORDER BY smart_contracts ASC) as rank FROM polygon_dapps WHERE network = 'Polygon';
# --------
#
# Prompt:What is the maximum safety rating for products in the skincare category that are not tested on animals?
# --------
# SQL of res: SELECT MAX(SafetyRating) AS MaxSafetyRating     FROM Products     WHERE Category = 'Skincare'     AND IsCrueltyFree = TRUE;
# SQL of truth: SELECT MAX(PS.SafetyRating) as HighestSafetyRating FROM ProductSafety PS JOIN Products P ON PS.ProductID = P.id JOIN CrueltyFreeCertification CFC ON P.id = CFC.ProductID WHERE P.Category = 'skincare' AND P.IsCrueltyFree = TRUE AND CFC.CertificationDate IS NOT NULL;
# --------
#
# Prompt:What is the total number of peacekeeping operations in the Middle East and their average duration?
# --------
# SQL of res: SELECT COUNT(*) AS total_peacekeeping_operations, AVG(DIFFWEEN end_date AND start_date) AS average_duration     FROM PeacekeepingOperationsMiddleEast;
# SQL of truth: SELECT COUNT(*) AS total_operations, AVG(end_date - start_date) AS avg_duration FROM PeacekeepingOperationsMiddleEast;
# --------
#
# Prompt:What is the total assets of clients who have invested in both stocks and bonds?
# --------
# SQL of res: SELECT SUM(total_assets) AS total_assets   FROM clients c   IN JOIN investments i ON c.client_id = i.client_id    WHERE investment_type = 'Stocks' AND investment_type = 'Bonds';
# SQL of truth: SELECT c.total_assets FROM clients c INNER JOIN investments i ON c.client_id = i.client_id WHERE i.investment_type IN ('Stocks', 'Bonds') GROUP BY c.client_id HAVING COUNT(DISTINCT i.investment_type) = 2;
# --------
#
# Prompt:What is the total population of all marine species in the Pacific ocean?
# --------
# SQL of res: -- Total population of all marine species in the Pacific ocean     SELECT SUM(population) AS total_population  FROM marine_species WHERE location = 'Pacific';
# SQL of truth: SELECT SUM(population) FROM marine_species WHERE location = 'Pacific';
# --------
#
# Prompt:What are the top 5 countries with the most broadband subscribers?
# --------
# SQL of res: SELECT country, COUNT(country) AS country_count FROM broadband_subscribers AS bs JOIN country_codes AS cc ON bs.country = cc.code LIMIT country_count GROUP BY country LIMIT country_count ORDER BY country_count DESC LIMIT country_count LIMIT country_count=5
# SQL of truth: SELECT bs.country, COUNT(bs.subscriber_id) AS num_subscribers FROM broadband_subscribers bs JOIN country_codes cc ON bs.country = cc.country GROUP BY bs.country ORDER BY num_subscribers DESC LIMIT 5;
# --------
#
# Prompt:What is the minimum price per kilogram of Gadolinium imported by South Korea from all countries in the last 5 years?
# --------
# SQL of res: SELECT MIN(price_PER_KG) AS min_price_per_kilogram FROM Gadolinium_Imports WHERE importing_country = 'South Korea'   AND year BETWEEN 2017 AND 2021;
# SQL of truth: SELECT MIN(price) FROM Gadolinium_Imports WHERE importing_country = 'South Korea' GROUP BY year ORDER BY year DESC LIMIT 5;
# --------
#
# Prompt:List the number of affordable housing units in each neighborhood of San Francisco.
# --------
# SQL of res: SELECT neighborhood ASC, COUNT(*) AS num_units FROM affordable_housing WHERE id = 1 AND neighborhood = neighborhood ORDER BY neighborhood ASC GROUP BY neighborhood ASC ORDER BY neighborhood ASC;
# SQL of truth: SELECT neighborhood, num_units FROM affordable_housing;
# --------
#
# Prompt:How many products in each category are available in the inventory?
# --------
# SQL of res: SELECT category, COUNT(*) AS product_count FROM products;  SELECT category, COUNT(*) AS product_count, quantity FROM products GROUP BY category;
# SQL of truth: SELECT category, COUNT(*) FROM products GROUP BY category;
# --------
#
# Prompt:Show the total workout duration for each workout type, excluding the ones that have a duration less than 30 minutes.
# --------
# SQL of res: SELECT workout_type, SUM(workout_duration) AS total_duration FROM workout_data_ext GROUP BY workout_type ORDER BY workout_type HAVING workout_duration >= 30;
# SQL of truth: SELECT workout_type, SUM(workout_duration) FROM workout_data_ext WHERE workout_duration >= 30 GROUP BY workout_type;
# --------
#
# Prompt:List community development initiatives and their funding sources from the 'rural_development' database
# --------
# SQL of res: SELECT      SELECT initiative, description, lead_organization, funding_source      FROM community_development      WHERE id = 1 OR id = 2
# SQL of truth: SELECT initiative, lead_organization, funding_source FROM community_development;
# --------
#
# Prompt:What was the number of attendees for events in the 'Theater' category?
# --------
# SQL of res: SELECT ea.attendee_count FROM events LEFT JOIN event_attendance ON events.id = ea.event_id WHERE events.category = 'Theater';
# SQL of truth: SELECT SUM(attendee_count) FROM event_attendance JOIN events ON event_attendance.event_id = events.id WHERE events.category = 'Theater';
# --------
#
# Prompt:What is the total production output of factories in each country?
# --------
# SQL of res: SELECT (     SELECT country, SUM(production_output) AS total_production_output     FROM factories      GROUP BY country ) AS country_total
# SQL of truth: SELECT country, SUM(production_output) FROM factories GROUP BY country;
# --------
#
# Prompt:Show all cybersecurity strategies along with their respective authors.
# --------
# SQL of res: SELECT strategy, author FROM cybersecurity_strategies; SELECT strategy, author FROM ( ) SELECT strategy, author FROM cybersecurity_strategies; SELECT strategy, author FROM (
# SQL of truth: SELECT strategy, author FROM cybersecurity_strategies;
# --------
#
# Prompt:How many games did each NBA team play in the 2021-2022 season?
# --------
# SQL of res: SELECT team, games AS games_played FROM (     SELECT team, games FROM (nba_schedule WHERE games = 82) ) GROUP BY team, games;
# SQL of truth: SELECT team, COUNT(*) as games FROM nba_schedule GROUP BY team;
# --------
#
# Prompt:What is the average number of eco-friendly tours offered per hotel in Paris?
# --------
# SQL of res: SELECT AVG(t.id) AS average_eco_tours FROM hotels h JOIN tours t ON h.id = t.hotel_id WHERE city_name = 'Paris';
# SQL of truth: SELECT AVG(t.eco_friendly) FROM tours t JOIN hotels h ON t.hotel_id = h.id WHERE h.city = 'Paris' AND t.eco_friendly = true;
# --------
#
# Prompt:List the booking dates and hotel names for all OTA bookings where the hotel has implemented at least one AI-powered solution.
# --------
# SQL of res: SELECT otas.booking_date, hotels.hotel_name FROM otas LEFT JOIN ai_solutions ON otas.hotel_id = ai_solutions.hotel_id WHERE hotels IS NOT NULL AND ai_solutions.hotel_id IS NOT NULL;
# SQL of truth: SELECT otas.booking_date, hotels.hotel_name FROM otas INNER JOIN hotels ON otas.hotel_id = hotels.hotel_id INNER JOIN ai_solutions ON hotels.hotel_id = ai_solutions.hotel_id GROUP BY otas.booking_date, hotels.hotel_name HAVING COUNT(DISTINCT ai_solutions.solution_id) >= 1;
# --------

# %%
print(complexity_eval_res)
# Out:
# {'basic SQL': {'err_res': 41, 'correct': 214, 'parsable': 283, 'total': 379, 'cell_intersect': 351, 'cell_predict': 449.000001, 'cell_gold': 536.000001}, 'aggregation': {'err_res': 34, 'correct': 59, 'parsable': 106, 'total': 157, 'cell_intersect': 498, 'cell_predict': 602.000001, 'cell_gold': 783.000001}, 'window functions': {'err_res': 7, 'correct': 3, 'parsable': 10, 'total': 21, 'cell_intersect': 62, 'cell_predict': 74.000001, 'cell_gold': 194.000001}, 'single join': {'err_res': 37, 'correct': 23, 'parsable': 45, 'total': 92, 'cell_intersect': 132, 'cell_predict': 179.000001, 'cell_gold': 290.000001}, 'multiple_joins': {'err_res': 9, 'correct': 1, 'parsable': 3, 'total': 13, 'cell_intersect': 9, 'cell_predict': 15.000001, 'cell_gold': 46.000001}, 'subqueries': {'err_res': 10, 'correct': 7, 'parsable': 19, 'total': 33, 'cell_intersect': 20, 'cell_predict': 41.000001, 'cell_gold': 75.000001}, 'set operations': {'err_res': 3, 'correct': 1, 'parsable': 1, 'total': 6, 'cell_intersect': 1, 'cell_predict': 1.000001, 'cell_gold': 12.000001}}

# %%
scores_by_complexity = {}

for complexity, counts in complexity_eval_res.items():
    print(f"Complexity: {complexity}, num. samples = {counts['total']}")
    print(f"   Macro stats -- correct:{counts['correct']/counts['total']:.2} | parsable: {counts['parsable']/counts['total']:.2}")
    precision = counts['cell_intersect']/counts['cell_predict']
    recall = counts['cell_intersect']/counts['cell_gold']
    print(f"   Cell stats -- precision:{precision:.2} | recall:{recall:.2} | F1: {(2 * precision * recall) / (precision + recall+1e-9)}")
    
    scores_by_complexity[complexity] = {
        "accuracy": counts['correct']/counts['total'],
        "parsable": counts['parsable']/counts['total'],
        "precision": precision,
        "recall": recall,
        "f1": (2 * precision * recall) / (precision + recall+1e-9)
    }
    # precision = intersection_count / total_predicted
    #recall = intersection_count / total_gold

# Overall stats
overall_counts = {"correct":0, "parsable":0, "total":0, "cell_intersect":0, "cell_predict":0.000001, "cell_gold": 0.000001}
for complexity, counts in complexity_eval_res.items():
    overall_counts['correct'] += counts['correct']
    overall_counts['parsable'] += counts['parsable']
    overall_counts['total'] += counts['total']
    overall_counts['cell_intersect'] += counts['cell_intersect']
    overall_counts['cell_predict'] += counts['cell_predict']
    overall_counts['cell_gold'] += counts['cell_gold']
# print(f"Overall Complexity: num. samples = {overall_counts['total']}")
# print(f"   Micro stats -- correct:{overall_counts['correct']/overall_counts['total']:.2} | parsable: {overall_counts['parsable']/overall_counts['total']:.2}")
# precision = overall_counts['cell_intersect']/overall_counts['cell_predict']
# recall = overall_counts['cell_intersect']/overall_counts['cell_gold']
# print(f"   Cell stats -- precision:{precision:.2} | recall:{recall:.2} | F1: {(2 * precision * recall) / (precision + recall+1e-9)}")
print("*" * 100)
print("Micro-averaged scores:")
micro_accuracy = overall_counts['correct']/overall_counts['total']
micro_parsable = overall_counts['parsable']/overall_counts['total']
micro_precision = overall_counts['cell_intersect']/overall_counts['cell_predict']
micro_recall = overall_counts['cell_intersect']/overall_counts['cell_gold']
micro_f1 = (2 * micro_precision * micro_recall) / (micro_precision + micro_recall+1e-9)
print(f"   Micro Accuracy: {micro_accuracy:.2}")
print(f"   Micro Parsable: {micro_parsable:.2}")
print(f"   Micro Precision: {micro_precision:.2}")
print(f"   Micro Recall: {micro_recall:.2}")


print("*" * 100)
# Macro accuracy, precision, recall and F1 can be calculated by averaging the values across complexities
print("Macro-averaged scores:")
macro_accuracy = sum([scores_by_complexity[comp]['accuracy'] for comp in scores_by_complexity]) / len(scores_by_complexity)
macro_parsable = sum([scores_by_complexity[comp]['parsable'] for comp in scores_by_complexity]) / len(scores_by_complexity)
macro_precision = sum([scores_by_complexity[comp]['precision'] for comp in scores_by_complexity]) / len(scores_by_complexity)
macro_recall = sum([scores_by_complexity[comp]['recall'] for comp in scores_by_complexity]) / len(scores_by_complexity)
macro_f1 = sum([scores_by_complexity[comp]['f1'] for comp in scores_by_complexity]) / len(scores_by_complexity)
print(f"   Macro Accuracy: {macro_accuracy:.2}")
print(f"   Macro Parsable: {macro_parsable:.2}")
print(f"   Macro Precision: {macro_precision:.2}")
print(f"   Macro Recall: {macro_recall:.2}")
# Out:
# Complexity: basic SQL, num. samples = 379
#    Macro stats -- correct:0.56 | parsable: 0.75
#    Cell stats -- precision:0.78 | recall:0.65 | F1: 0.7126903533867629
# Complexity: aggregation, num. samples = 157
#    Macro stats -- correct:0.38 | parsable: 0.68
#    Cell stats -- precision:0.83 | recall:0.64 | F1: 0.7191335724772995
# Complexity: window functions, num. samples = 21
#    Macro stats -- correct:0.14 | parsable: 0.48
#    Cell stats -- precision:0.84 | recall:0.32 | F1: 0.4626865633115393
# Complexity: single join, num. samples = 92
#    Macro stats -- correct:0.25 | parsable: 0.49
#    Cell stats -- precision:0.74 | recall:0.46 | F1: 0.5628997839079656
# Complexity: multiple_joins, num. samples = 13
#    Macro stats -- correct:0.077 | parsable: 0.23
#    Cell stats -- precision:0.6 | recall:0.2 | F1: 0.29508195716742847
# Complexity: subqueries, num. samples = 33
#    Macro stats -- correct:0.21 | parsable: 0.58
#    Cell stats -- precision:0.49 | recall:0.27 | F1: 0.3448275798045483
# Complexity: set operations, num. samples = 6
#    Macro stats -- correct:0.17 | parsable: 0.17
#    Cell stats -- precision:1.0 | recall:0.083 | F1: 0.15384613003550648
# ****************************************************************************************************
# Micro-averaged scores:
#    Micro Accuracy: 0.44
#    Micro Parsable: 0.67
#    Micro Precision: 0.79
#    Micro Recall: 0.55
# ****************************************************************************************************
# Macro-averaged scores:
#    Macro Accuracy: 0.26
#    Macro Parsable: 0.48
#    Macro Precision: 0.75
#    Macro Recall: 0.37

# %%
# 1. Print the Table Headers
print(r"\begin{table*}[tp]")
print(r"\centering")
# Column defs: l (text), r (num), | (divider), rrr (macro), | (divider), rrr (cell)
print(r"\begin{tabular}{l r | rrr | rrr}") 
print(r"\toprule")
print(r" & & \multicolumn{3}{c|}{\textbf{Macro Stats}} & \multicolumn{3}{c}{\textbf{Cell Stats}} \\")
print(r"\textbf{Complexity} & \textbf{Samples} & \textbf{Error/Parsable} & \textbf{Correct} & \textbf{Parsable} & \textbf{Precision} & \textbf{Recall} & \textbf{F1} \\")
print(r"\midrule")

# 2. Iterate and Print Rows
for complexity, counts in complexity_eval_res.items():
    # --- Metric Calculations (From your code) ---
    total = counts['total']
    err_pars_ratio = counts['err_res']/counts['parsable'] if counts['parsable'] > 0 else 0
    # Avoid division by zero
    accuracy = counts['correct'] / total if total > 0 else 0
    parsable = counts['parsable'] / total if total > 0 else 0
    
    precision = counts['cell_intersect'] / counts['cell_predict'] if counts['cell_predict'] > 0 else 0
    recall = counts['cell_intersect'] / counts['cell_gold'] if counts['cell_gold'] > 0 else 0
    f1 = (2 * precision * recall) / (precision + recall + 1e-9)

    # --- Row Formatting ---
    # We use f-string formatting. 
    # {variable:.2f} rounds to 2 decimal places.
    # \\\\ prints a double backslash for LaTeX line endings.
    row_str = (
        f"{complexity} & "
        f"{total} & "
        f"{err_pars_ratio:.2f} & " # The missing metric
        f"{accuracy:.2f} & "
        f"{parsable:.2f} & "
        f"{precision:.2f} & "
        f"{recall:.2f} & "
        f"{f1:.2f} \\\\"
    )
    
    print(row_str)

# 3. Print Table Footer
print(r"\bottomrule")
print(r"\end{tabular}")
print(r"\caption{Baseline Evaluation Metrics by SQL Query Complexity}")
print(r"\label{tab:complexity-metrics-full}")
print(r"\end{table*}")
# Out:
# \begin{table*}[tp]
# \centering
# \begin{tabular}{l r | rrr | rrr}
# \toprule
#  & & \multicolumn{3}{c|}{\textbf{Macro Stats}} & \multicolumn{3}{c}{\textbf{Cell Stats}} \\
# \textbf{Complexity} & \textbf{Samples} & \textbf{Error/Parsable} & \textbf{Correct} & \textbf{Parsable} & \textbf{Precision} & \textbf{Recall} & \textbf{F1} \\
# \midrule
# basic SQL & 379 & 0.14 & 0.56 & 0.75 & 0.78 & 0.65 & 0.71 \\
# aggregation & 157 & 0.32 & 0.38 & 0.68 & 0.83 & 0.64 & 0.72 \\
# window functions & 21 & 0.70 & 0.14 & 0.48 & 0.84 & 0.32 & 0.46 \\
# single join & 92 & 0.82 & 0.25 & 0.49 & 0.74 & 0.46 & 0.56 \\
# multiple_joins & 13 & 3.00 & 0.08 & 0.23 & 0.60 & 0.20 & 0.30 \\
# subqueries & 33 & 0.53 & 0.21 & 0.58 & 0.49 & 0.27 & 0.34 \\
# set operations & 6 & 3.00 & 0.17 & 0.17 & 1.00 & 0.08 & 0.15 \\
# \bottomrule
# \end{tabular}
# \caption{Baseline Evaluation Metrics by SQL Query Complexity}
# \label{tab:complexity-metrics-full}
# \end{table*}
